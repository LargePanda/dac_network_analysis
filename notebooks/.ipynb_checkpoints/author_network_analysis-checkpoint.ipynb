# %% [markdown]
# <h1 align="center">DAC Author Network Analysis</h1>

# %% [markdown]
# Reference:
# [1] Modularity and community structure in networks http://www.pnas.org/content/103/23/8577.full.pdf
# [2] The structure of scientific collaboration networks http://www.pnas.org/content/98/2/404.full.pdf
# [3] D. Liben-Nowell, J. Kleinberg. The Link Prediction Problem for Social Networks (2004). http://www.cs.cornell.edu/home/kleinber/link-pred.pdf

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import networkx as nx
from DAC import Author
from DAC import Paper
import pandas as pd
import pickle
import pyprind
import community
import operator

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
matplotlib.rcParams.update({'font.size': 14})

# %%
with open("../process_data/Author_Data.pickle", "rb") as f:
    authors = pickle.load(f)

# %%
with open("../process_data/Paper_Data.pickle", "rb") as f:
    papers = pickle.load(f)

# %%
authors['643'].__dict__
# Out:
# {'aid': '643',
#  'name': u'Jason M. Weaver',
#  'nicknames': [u'Jason Weaver'],
#  'paper_ids': [u'DETC2008-49891 pp. 351-366; (16 pages)',
#   u'DETC2011-48359, pp. 325-339']}

# %%
aus = {}

for a in authors.values():
    aus[a.aid] = a.__dict__
    
for au in aus.values():
    au['colls'] = 0
    for p in au['paper_ids']:
        au['colls'] += len(papers[p].author_ids)

# %%
rank = {}

for a in aus.values():
    rank[a] =
# Out:
# {'344': {'aid': '344',
#   'colls': 8,
#   'name': u'Christian Noon',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86496 pp. 151-161; (11 pages)',
#    u'DETC2007-35390 pp. 1403-1413; (11 pages)']},
#  '345': {'aid': '345',
#   'colls': 8,
#   'name': u'Daniel D. Frey',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85486 pp. 437-446; (10 pages)',
#    u'DETC2007-34926 pp. 285-295; (11 pages)',
#    u'DETC2005-85490 pp. 1273-1281; (9 pages)']},
#  '346': {'aid': '346',
#   'colls': 28,
#   'name': u'Xiaolong Feng',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48196, pp. 867-876',
#    u'DETC2010-28488, pp. 815-823',
#    u'DETC2007-34772 pp. 903-910; (8 pages)',
#    u'DETC2012-70867, pp. 833-845',
#    u'DETC2008-49645 pp. 777-787; (11 pages)',
#    u'DETC2011-47819, pp. 815-823',
#    u'DETC2009-86613 pp. 927-939; (13 pages)']},
#  '347': {'aid': '347',
#   'colls': 1,
#   'name': u'J. Schiffmann',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12180, pp. V03BT03A031']},
#  '340': {'aid': '340',
#   'colls': 18,
#   'name': u'Richard Gonzalez',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35440, pp. V02AT03A012',
#    u'DETC2013-13020, pp. V03BT03A004',
#    u'DETC2010-29055, pp. 715-728',
#    u'DETC2007-35580 pp. 219-228; (10 pages)']},
#  '341': {'aid': '341',
#   'colls': 23,
#   'name': u'Rahul Rai',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99178 pp. 381-391; (11 pages)',
#    u'DETC2011-47743, pp. 987-996',
#    u'DETC2014-34065, pp. V02AT03A005',
#    u'DETC2013-12271, pp. V03BT03A025',
#    u'DETC2012-70493, pp. 533-540',
#    u'DETC2007-34520 pp. 649-662; (14 pages)',
#    u'DETC2015-46087, pp. V02AT03A048',
#    u'DETC2002/DAC-34088 pp. 495-503; (9 pages)']},
#  '342': {'aid': '342',
#   'colls': 2,
#   'name': u'Beiqing Huang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84523 pp. 1143-1152; (10 pages)']},
#  '343': {'aid': '343',
#   'colls': 4,
#   'name': u'Peter J. Hesketh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57582 pp. 1101-1109; (9 pages)']},
#  '348': {'aid': '348',
#   'colls': 11,
#   'name': u'Nicholas J. Gaul',
#   'nicknames': [u'Nicholas Gaul'],
#   'paper_ids': [u'DETC2015-47370, pp. V02BT03A060',
#    u'DETC2015-46982, pp. V02BT03A057']},
#  '349': {'aid': '349',
#   'colls': 3,
#   'name': u'Zheng Fan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34063 pp. 251-256; (6 pages)']},
#  '2318': {'aid': '2318',
#   'colls': 13,
#   'name': u'Matthew P. Reed',
#   'nicknames': [u'Matthew Reed'],
#   'paper_ids': [u'DETC2008-49483 pp. 561-569; (9 pages)',
#    u'DETC2005-84179 pp. 1103-1109; (7 pages)',
#    u'DETC2006-99429 pp. 133-139; (7 pages)',
#    u'DETC2002/DAC-34091 pp. 529-537; (9 pages)']},
#  '2319': {'aid': '2319',
#   'colls': 3,
#   'name': u'Y. Kang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34145 pp. 1031-1036; (6 pages)']},
#  '2316': {'aid': '2316',
#   'colls': 5,
#   'name': u'Teng Long',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34594, pp. V02BT03A022']},
#  '2317': {'aid': '2317',
#   'colls': 5,
#   'name': u'Avinash Kolla',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28557, pp. 43-49']},
#  '2314': {'aid': '2314',
#   'colls': 2,
#   'name': u'Jeff Thielman',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57446 pp. 829-835; (7 pages)']},
#  '2315': {'aid': '2315',
#   'colls': 19,
#   'name': u'Tomonori Honda',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48749, pp. 231-240',
#    u'DETC2012-70468, pp. 379-390',
#    u'DETC2014-35032, pp. V02AT03A024',
#    u'DETC2005-85111 pp. 401-412; (12 pages)',
#    u'DETC2013-12514, pp. V03AT03A035']},
#  '2312': {'aid': '2312',
#   'colls': 5,
#   'name': u'Alex M. Ruderman',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87074 pp. 433-444; (12 pages)']},
#  '2313': {'aid': '2313',
#   'colls': 3,
#   'name': u'Andreas Kain',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-50123 pp. 605-615; (11 pages)']},
#  '2310': {'aid': '2310',
#   'colls': 2,
#   'name': u'Ashish Macwan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84888 pp. 979-988; (10 pages)']},
#  '2311': {'aid': '2311',
#   'colls': 5,
#   'name': u'Amir H. Birjandi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49991 pp. 531-541; (11 pages)']},
#  '298': {'aid': '298',
#   'colls': 3,
#   'name': u'Y. Rong',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34145 pp. 1031-1036; (6 pages)']},
#  '299': {'aid': '299',
#   'colls': 5,
#   'name': u'Haobo Qiu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47130, pp. 533-541']},
#  '296': {'aid': '296',
#   'colls': 12,
#   'name': u'Weiyang Tong',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35572, pp. V02AT03A017',
#    u'DETC2013-13181, pp. V03BT03A037',
#    u'DETC2013-13196, pp. V03AT03A024']},
#  '297': {'aid': '297',
#   'colls': 5,
#   'name': u'Fabien Nicaise',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35307 pp. 1351-1358; (8 pages)',
#    u'DETC2005-85111 pp. 401-412; (12 pages)']},
#  '294': {'aid': '294',
#   'colls': 3,
#   'name': u'Erin Roach',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48435, pp. 741-751']},
#  '295': {'aid': '295',
#   'colls': 3,
#   'name': u'Jaime Gallardo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34093 pp. 549-557; (9 pages)']},
#  '292': {'aid': '292',
#   'colls': 6,
#   'name': u'Steven Sieczka',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99393 pp. 663-670; (8 pages)']},
#  '293': {'aid': '293',
#   'colls': 9,
#   'name': u'Charlie Manion',
#   'nicknames': [u'Charles A. Manion'],
#   'paper_ids': [u'DETC2013-12357, pp. V03BT03A007',
#    u'DETC2015-46078, pp. V02AT03A004']},
#  '290': {'aid': '290',
#   'colls': 5,
#   'name': u'Charles Friesen',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34118 pp. 791-798; (8 pages)']},
#  '291': {'aid': '291',
#   'colls': 5,
#   'name': u'Lalit Patil',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49871 pp. 961-968; (8 pages)']},
#  '270': {'aid': '270',
#   'colls': 3,
#   'name': u'David Chang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48721 pp. 175-185; (11 pages)']},
#  '271': {'aid': '271',
#   'colls': 3,
#   'name': u'Samuel Sai-Man Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35010 pp. 849-858; (10 pages)']},
#  '273': {'aid': '273',
#   'colls': 2,
#   'name': u'Ahmed A. Shabana',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34094 pp. 559-566; (8 pages)']},
#  '274': {'aid': '274',
#   'colls': 5,
#   'name': u'Toufic Zaraket',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70835, pp. 299-308']},
#  '275': {'aid': '275',
#   'colls': 4,
#   'name': u'Alok Choudhary',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34570, pp. V02BT03A009']},
#  '276': {'aid': '276',
#   'colls': 3,
#   'name': u'Jun Tang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48711 pp. 73-83; (11 pages)']},
#  '277': {'aid': '277',
#   'colls': 2,
#   'name': u'Ilan M. Kroo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-50038 pp. 927-936; (10 pages)']},
#  '278': {'aid': '278',
#   'colls': 8,
#   'name': u'Combiz Jelveh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70484, pp. 151-156']},
#  '279': {'aid': '279',
#   'colls': 4,
#   'name': u'Marie-Jos\xe9e Potvin',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34066 pp. 275-282; (8 pages)']},
#  '2268': {'aid': '2268',
#   'colls': 5,
#   'name': u'Jae-Yong Park',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87268 pp. 1183-1191; (9 pages)']},
#  '2269': {'aid': '2269',
#   'colls': 3,
#   'name': u'Shutian Liu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28856, pp. 1201-1208']},
#  '1132': {'aid': '1132',
#   'colls': 2,
#   'name': u'Abhinav S. Singh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47439, pp. V02BT03A020']},
#  '2262': {'aid': '2262',
#   'colls': 3,
#   'name': u'Liangkai Ma',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57183 pp. 267-278; (12 pages)']},
#  '2263': {'aid': '2263',
#   'colls': 21,
#   'name': u'Zequn Wang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12608, pp. V03BT03A052',
#    u'DETC2015-47003, pp. V02BT03A058',
#    u'DETC2014-34546, pp. V02BT03A048',
#    u'DETC2014-34552, pp. V02AT03A039',
#    u'DETC2013-12598, pp. V03AT03A047',
#    u'DETC2014-34550, pp. V02AT03A038',
#    u'DETC2014-34549, pp. V02BT03A049',
#    u'DETC2012-70790, pp. 735-744']},
#  '2260': {'aid': '2260',
#   'colls': 18,
#   'name': u'Takayuki Yamada',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86594 pp. 871-880; (10 pages)',
#    u'DETC2009-86618 pp. 1279-1286; (8 pages)',
#    u'DETC2012-70235, pp. 857-862',
#    u'DETC2008-49618 pp. 1217-1225; (9 pages)']},
#  '2261': {'aid': '2261',
#   'colls': 4,
#   'name': u'Cheng Feng Zhu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48749 pp. 439-447; (9 pages)']},
#  '2266': {'aid': '2266',
#   'colls': 17,
#   'name': u'Michael A. Yukish',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13098, pp. V03AT03A014',
#    u'DETC2015-46909, pp. V02AT03A020',
#    u'DETC2014-34503, pp. V02AT03A052']},
#  '2267': {'aid': '2267',
#   'colls': 3,
#   'name': u'S. Rahman',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85146 pp. 773-783; (11 pages)']},
#  '2264': {'aid': '2264',
#   'colls': 21,
#   'name': u'Damiano Pasini',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47983, pp. 945-954',
#    u'DETC2010-28158, pp. 11-20',
#    u'DETC2011-47487, pp. 935-944',
#    u'DETC2010-28730, pp. 51-58',
#    u'DETC2008-50106 pp. 1247-1253; (7 pages)',
#    u'DETC2010-28462, pp. 1181-1189',
#    u'DETC2009-87540 pp. 1315-1323; (9 pages)',
#    u'DETC2011-47390, pp. 925-934']},
#  '2265': {'aid': '2265',
#   'colls': 3,
#   'name': u'M. A. M. Victor',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86123 pp. 3-12; (10 pages)']},
#  '2442': {'aid': '2442',
#   'colls': 3,
#   'name': u'T. Zhang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85146 pp. 773-783; (11 pages)']},
#  '2443': {'aid': '2443',
#   'colls': 3,
#   'name': u'Beno\xeet Eynard',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48746 pp. 419-424; (6 pages)']},
#  '2440': {'aid': '2440',
#   'colls': 4,
#   'name': u'Seungjae Oh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48933, pp. 173-182']},
#  '2441': {'aid': '2441',
#   'colls': 3,
#   'name': u'Brendan T. O\u2019Connor',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47610, pp. V02BT03A013']},
#  '2446': {'aid': '2446',
#   'colls': 6,
#   'name': u'Hirofumi Amaya',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47853, pp. 577-589',
#    u'DETC2010-28662, pp. 277-290']},
#  '2447': {'aid': '2447',
#   'colls': 4,
#   'name': u'Ralph Stelzer',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28208, pp. 407-414']},
#  '2444': {'aid': '2444',
#   'colls': 4,
#   'name': u'William Gaziza',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34045, pp. V02AT03A050']},
#  '2445': {'aid': '2445',
#   'colls': 5,
#   'name': u'Richard Gerth',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13020, pp. V03BT03A004']},
#  '2448': {'aid': '2448',
#   'colls': 3,
#   'name': u'Kurt Sermeus',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28782, pp. 487-495']},
#  '2449': {'aid': '2449',
#   'colls': 4,
#   'name': u'Tolga Kurtoglu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47888, pp. 1169-1178']},
#  '2189': {'aid': '2189',
#   'colls': 4,
#   'name': u'Farhad Javid',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28462, pp. 1181-1189']},
#  '108': {'aid': '108',
#   'colls': 4,
#   'name': u'Subroto Gunawan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99458 pp. 1157-1168; (12 pages)',
#    u'DETC2005-84514 pp. 1133-1142; (10 pages)']},
#  '109': {'aid': '109',
#   'colls': 3,
#   'name': u'You-Tern Tsai',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70182, pp. 567-575']},
#  '102': {'aid': '102',
#   'colls': 30,
#   'name': u'Fabrice Alizon',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87534 pp. 407-418; (12 pages)',
#    u'DETC2007-34510 pp. 941-948; (8 pages)',
#    u'DETC2008-49428 pp. 1011-1017; (7 pages)',
#    u'DETC2006-99499 pp. 899-909; (11 pages)',
#    u'DETC2006-99538 pp. 911-920; (10 pages)',
#    u'DETC2007-34507 pp. 931-940; (10 pages)',
#    u'DETC2008-49429 pp. 1019-1029; (11 pages)']},
#  '103': {'aid': '103',
#   'colls': 3,
#   'name': u'Nicholas S. Wasley',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71209, pp. 463-470']},
#  '100': {'aid': '100',
#   'colls': 4,
#   'name': u'I. Jessica Hidalgo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99551 pp. 745-756; (12 pages)',
#    u'DETC2007-35825 pp. 371-385; (15 pages)']},
#  '101': {'aid': '101',
#   'colls': 2,
#   'name': u'Chun-Yu Lin',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71186, pp. 167-177']},
#  '106': {'aid': '106',
#   'colls': 2,
#   'name': u'Alan Bowling',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48835 pp. 1231-1237; (7 pages)']},
#  '107': {'aid': '107',
#   'colls': 9,
#   'name': u'Gopal Nadadur',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12845, pp. V03BT03A018',
#    u'DETC2010-28879, pp. 391-398',
#    u'DETC2012-70727, pp. 931-940']},
#  '104': {'aid': '104',
#   'colls': 7,
#   'name': u'J. K. Allen',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49395 pp. 823-840; (18 pages)']},
#  '105': {'aid': '105',
#   'colls': 4,
#   'name': u'Bj\xf6rn Johansson',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85428 pp. 91-99; (9 pages)',
#    u'DETC2007-35329 pp. 911-920; (10 pages)']},
#  '2046': {'aid': '2046',
#   'colls': 4,
#   'name': u'L. Luo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57405 pp. 729-738; (10 pages)']},
#  '2047': {'aid': '2047',
#   'colls': 8,
#   'name': u'Jie Hu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12460, pp. V03BT03A028',
#    u'DETC2015-46373, pp. V02AT03A006',
#    u'DETC2004-57224 pp. 341-349; (9 pages)']},
#  '2044': {'aid': '2044',
#   'colls': 4,
#   'name': u'Hakan U. Artar',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35672 pp. 1029-1038; (10 pages)']},
#  '2045': {'aid': '2045',
#   'colls': 9,
#   'name': u'Richard A. Wysk',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99211 pp. 207-214; (8 pages)',
#    u'DETC2011-48148, pp. 281-290',
#    u'DETC2004-57440 pp. 811-817; (7 pages)']},
#  '2042': {'aid': '2042',
#   'colls': 29,
#   'name': u'Chao Hu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87713 pp. 1239-1249; (11 pages)',
#    u'DETC2011-48850, pp. 155-164',
#    u'DETC2010-29183, pp. 1133-1148',
#    u'DETC2013-13592, pp. V03AT03A039',
#    u'DETC2013-12601, pp. V03AT03A037',
#    u'DETC2012-70529, pp. 333-347',
#    u'DETC2011-48314, pp. 1179-1188',
#    u'DETC2013-12593, pp. V03AT03A036',
#    u'DETC2015-46964, pp. V02AT03A039']},
#  '2043': {'aid': '2043',
#   'colls': 7,
#   'name': u'Erdem Acar',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85064 pp. 1225-1232; (8 pages)',
#    u'DETC2008-49168 pp. 1109-1122; (14 pages)']},
#  '2041': {'aid': '2041',
#   'colls': 2,
#   'name': u'Kunjal Oza',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57463 pp. 885-891; (7 pages)']},
#  '2048': {'aid': '2048',
#   'colls': 4,
#   'name': u'Kyoung-Yun Joseph Kim',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49900 pp. 43-51; (9 pages)']},
#  '2038': {'aid': '2038',
#   'colls': 3,
#   'name': u'Fjola Jonsdottir',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85342 pp. 331-336; (6 pages)']},
#  '1210': {'aid': '1210',
#   'colls': 4,
#   'name': u'A. Diaz',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48755 pp. 503-512; (10 pages)']},
#  '99': {'aid': '99',
#   'colls': 1,
#   'name': u'Madhusudan Raghavan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48810 pp. 1019-1024; (6 pages)']},
#  '98': {'aid': '98',
#   'colls': 10,
#   'name': u'Kristina W\xe4rmefjord',
#   'nicknames': [u'Kristina Wa\u0308rmefjord'],
#   'paper_ids': [u'DETC2013-13029, pp. V03BT03A009',
#    u'DETC2008-49708 pp. 693-700; (8 pages)',
#    u'DETC2011-48393, pp. 697-704']},
#  '91': {'aid': '91',
#   'colls': 2,
#   'name': u'Weihang Zhu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86129 pp. 489-496; (8 pages)',
#    u'DETC2010-28102, pp. 315-323']},
#  '90': {'aid': '90',
#   'colls': 4,
#   'name': u'Pulkit Shamshery',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47519, pp. V02AT03A021']},
#  '93': {'aid': '93',
#   'colls': 3,
#   'name': u'Chao Qi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35308, pp. V02BT03A035']},
#  '92': {'aid': '92',
#   'colls': 4,
#   'name': u'Claudio Favi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70997, pp. 1339-1348']},
#  '95': {'aid': '95',
#   'colls': 5,
#   'name': u'T. R. Langerak',
#   'nicknames': [u'Thomas R. Langerak'],
#   'paper_ids': [u'DETC2005-84813 pp. 1301-1308; (8 pages)',
#    u'DETC2007-34796 pp. 829-838; (10 pages)']},
#  '94': {'aid': '94',
#   'colls': 6,
#   'name': u'Tomotake Furuhata',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34074 pp. 353-360; (8 pages)',
#    u'DETC2003/DAC-48778 pp. 721-735; (15 pages)']},
#  '97': {'aid': '97',
#   'colls': 4,
#   'name': u'C. Yu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85284 pp. 719-727; (9 pages)']},
#  '96': {'aid': '96',
#   'colls': 9,
#   'name': u'Sinobu Yoshimura',
#   'nicknames': [u'Shinobu Yoshimura'],
#   'paper_ids': [u'DETC2002/DAC-34048 pp. 141-148; (8 pages)',
#    u'DETC2002/DAC-34059 pp. 217-223; (7 pages)',
#    u'DETC2003/DAC-48764 pp. 587-595; (9 pages)']},
#  '1991': {'aid': '1991',
#   'colls': 2,
#   'name': u'Zhiqiang Chen',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34842 pp. 151-161; (11 pages)']},
#  '1622': {'aid': '1622',
#   'colls': 18,
#   'name': u'F. W. Liou',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99631 pp. 983-991; (9 pages)',
#    u'DETC2005-85163 pp. 1309-1319; (11 pages)',
#    u'DETC2003/DAC-48780 pp. 745-754; (10 pages)',
#    u'DETC2002/DAC-34138 pp. 965-971; (7 pages)',
#    u'DETC2003/DAC-48726 pp. 227-235; (9 pages)']},
#  '1621': {'aid': '1621',
#   'colls': 3,
#   'name': u'J. I. Bailey',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48738 pp. 349-356; (8 pages)']},
#  '1620': {'aid': '1620',
#   'colls': 4,
#   'name': u'Kevin Drost',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57229 pp. 369-378; (10 pages)']},
#  '1627': {'aid': '1627',
#   'colls': 2,
#   'name': u'Brayan S. D\u2019Souza',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34106 pp. 681-690; (10 pages)']},
#  '1626': {'aid': '1626',
#   'colls': 2,
#   'name': u'Kalie Porterfield',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71151, pp. 553-565']},
#  '1624': {'aid': '1624',
#   'colls': 5,
#   'name': u'Zhiguang Qian',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57486 pp. 963-972; (10 pages)']},
#  '1998': {'aid': '1998',
#   'colls': 3,
#   'name': u'A. R. Rao',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84685 pp. 155-164; (10 pages)']},
#  '1629': {'aid': '1629',
#   'colls': 3,
#   'name': u'Hlynur Kristinsson',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85342 pp. 331-336; (6 pages)']},
#  '1628': {'aid': '1628',
#   'colls': 6,
#   'name': u'Lorri A. Bennett',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13098, pp. V03AT03A014']},
#  '559': {'aid': '559',
#   'colls': 4,
#   'name': u'D. Scott Hesser',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99676 pp. 371-380; (10 pages)']},
#  '558': {'aid': '558',
#   'colls': 5,
#   'name': u'Zhijun Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99467 pp. 199-206; (8 pages)']},
#  '555': {'aid': '555',
#   'colls': 4,
#   'name': u'V. Mehrad',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28550, pp. 229-239']},
#  '554': {'aid': '554',
#   'colls': 6,
#   'name': u'H. Wang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34146 pp. 1037-1045; (9 pages)']},
#  '557': {'aid': '557',
#   'colls': 3,
#   'name': u'Abir Z. Qamhiyah',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48847 pp. 1343-1350; (8 pages)']},
#  '556': {'aid': '556',
#   'colls': 10,
#   'name': u'Anthony Florita',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46849, pp. V02AT03A027',
#    u'DETC2014-34775, pp. V02AT03A022']},
#  '551': {'aid': '551',
#   'colls': 59,
#   'name': u'Achille Messac',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-29129, pp. 775-790',
#    u'DETC2014-35572, pp. V02AT03A017',
#    u'DETC2007-35385 pp. 1211-1225; (15 pages)',
#    u'DETC2002/DAC-34125 pp. 859-870; (12 pages)',
#    u'DETC2011-48731, pp. 367-378',
#    u'DETC2013-13181, pp. V03BT03A037',
#    u'DETC2014-35358, pp. V02BT03A026',
#    u'DETC2005-85147 pp. 199-211; (13 pages)',
#    u'DETC2008-50068 pp. 977-987; (11 pages)',
#    u'DETC2006-99322 pp. 845-861; (17 pages)',
#    u'DETC2011-48608, pp. 775-790',
#    u'DETC2005-85041 pp. 743-757; (15 pages)',
#    u'DETC2010-29121, pp. 729-744',
#    u'DETC2013-13196, pp. V03AT03A024',
#    u'DETC2013-12695, pp. V03AT03A021',
#    u'DETC2012-70954, pp. 983-999',
#    u'DETC2015-47188, pp. V02BT03A025']},
#  '550': {'aid': '550',
#   'colls': 19,
#   'name': u'Trevor Bailey',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57350 pp. 605-611; (7 pages)',
#    u'DETC2004-57299 pp. 473-479; (7 pages)',
#    u'DETC2008-49335 pp. 999-1009; (11 pages)',
#    u'DETC2008-49336 pp. 1255-1264; (10 pages)']},
#  '553': {'aid': '553',
#   'colls': 4,
#   'name': u'Howie Choset',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48726 pp. 227-235; (9 pages)']},
#  '552': {'aid': '552',
#   'colls': 3,
#   'name': u'Masanori Kuriyama',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35189 pp. 15-27; (13 pages)']},
#  '1199': {'aid': '1199',
#   'colls': 4,
#   'name': u'Gerald R. Bourne',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99329 pp. 481-489; (9 pages)']},
#  '1198': {'aid': '1198',
#   'colls': 3,
#   'name': u'Vasileios Geroulas',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46847, pp. V02BT03A054']},
#  '1191': {'aid': '1191',
#   'colls': 2,
#   'name': u'Ang Liu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12402, pp. V03BT03A040']},
#  '1190': {'aid': '1190',
#   'colls': 4,
#   'name': u'Minkyu Park',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48933, pp. 173-182']},
#  '1193': {'aid': '1193',
#   'colls': 9,
#   'name': u'Santosh Tiwari',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35497 pp. 29-38; (10 pages)',
#    u'DETC2006-99271 pp. 609-618; (10 pages)',
#    u'DETC2008-50097 pp. 543-552; (10 pages)']},
#  '1192': {'aid': '1192',
#   'colls': 2,
#   'name': u'D. Kalenchuk',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34144 pp. 1019-1030; (12 pages)']},
#  '1194': {'aid': '1194',
#   'colls': 22,
#   'name': u'D. Xue',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84956 pp. 109-122; (14 pages)',
#    u'DETC2004-57332 pp. 553-564; (12 pages)',
#    u'DETC2005-84425 pp. 253-263; (11 pages)',
#    u'DETC2009-86263 pp. 909-918; (10 pages)',
#    u'DETC2007-35179 pp. 237-248; (12 pages)',
#    u'DETC2010-28550, pp. 229-239',
#    u'DETC2004-57331 pp. 541-552; (12 pages)']},
#  '1197': {'aid': '1197',
#   'colls': 6,
#   'name': u'Jin Hui Kim',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71086, pp. 1051-1062']},
#  '1196': {'aid': '1196',
#   'colls': 6,
#   'name': u'Yuanzhang Sun',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46849, pp. V02AT03A027']},
#  '1759': {'aid': '1759',
#   'colls': 3,
#   'name': u'Chad McKonly',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48799 pp. 917-925; (9 pages)']},
#  '1758': {'aid': '1758',
#   'colls': 13,
#   'name': u'Annette Skowronska',
#   'nicknames': [u'Annette G. Skowronska'],
#   'paper_ids': [u'DETC2014-34294, pp. V02BT03A045',
#    u'DETC2015-46625, pp. V02BT03A051',
#    u'DETC2013-12376, pp. V03BT03A050']},
#  '1757': {'aid': '1757',
#   'colls': 6,
#   'name': u'Frans G. M. Kokkeler',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34421 pp. 563-570; (8 pages)']},
#  '1756': {'aid': '1756',
#   'colls': 8,
#   'name': u'Andy Dong',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13248, pp. V03AT03A048',
#    u'DETC2014-34407, pp. V02AT03A051']},
#  '1755': {'aid': '1755',
#   'colls': 16,
#   'name': u'Erich Devendorf',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-50006 pp. 273-284; (12 pages)',
#    u'DETC2010-28872, pp. 547-559',
#    u'DETC2011-48375, pp. 207-219',
#    u'DETC2012-71015, pp. 485-495',
#    u'DETC2013-13315, pp. V03BT03A034',
#    u'DETC2011-48377, pp. 891-902',
#    u'DETC2009-87517 pp. 997-1008; (12 pages)']},
#  '1753': {'aid': '1753',
#   'colls': 5,
#   'name': u'Marco Gero Fern\xe1ndez',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85322 pp. 413-426; (14 pages)']},
#  '1752': {'aid': '1752',
#   'colls': 3,
#   'name': u'Sreeram Ramakrishnan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57195 pp. 293-302; (10 pages)']},
#  '1751': {'aid': '1751',
#   'colls': 63,
#   'name': u'Michael Kokkolaras',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46967, pp. V02BT03A045',
#    u'DETC2005-84928 pp. 1173-1182; (10 pages)',
#    u'DETC2005-84790 pp. 265-275; (11 pages)',
#    u'DETC2007-34698 pp. 709-718; (10 pages)',
#    u'DETC2014-34772, pp. V02BT03A030',
#    u'DETC2002/DAC-34099 pp. 613-621; (9 pages)',
#    u'DETC2014-34778, pp. V02BT03A023',
#    u'DETC2015-46965, pp. V02BT03A044',
#    u'DETC2004-57357 pp. 613-624; (12 pages)',
#    u'DETC2006-99229 pp. 801-810; (10 pages)',
#    u'DETC2012-70423, pp. 1167-1177',
#    u'DETC2013-12352, pp. V03BT03A049',
#    u'DETC2005-84179 pp. 1103-1109; (7 pages)',
#    u'DETC2011-47234, pp. 1089-1098',
#    u'DETC2006-99467 pp. 199-206; (8 pages)',
#    u'DETC2010-28431, pp. 1023-1031']},
#  '1176': {'aid': '1176',
#   'colls': 5,
#   'name': u'Y. I. Kim',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84794 pp. 627-636; (10 pages)']},
#  '1175': {'aid': '1175',
#   'colls': 7,
#   'name': u'Charles L. Penninger',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70613, pp. 1261-1270',
#    u'DETC2009-86348 pp. 1267-1278; (12 pages)']},
#  '1174': {'aid': '1174',
#   'colls': 11,
#   'name': u'Koetsu Yamazaki',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34940 pp. 387-396; (10 pages)',
#    u'DETC2003/DAC-48804 pp. 961-967; (7 pages)',
#    u'DETC2007-35637 pp. 405-411; (7 pages)']},
#  '1173': {'aid': '1173',
#   'colls': 2,
#   'name': u'Yesh P. Singh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34057 pp. 191-206; (16 pages)']},
#  '1172': {'aid': '1172',
#   'colls': 2,
#   'name': u'Ramesh Lakshmipathy',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34142 pp. 1003-1009; (7 pages)']},
#  '1171': {'aid': '1171',
#   'colls': 4,
#   'name': u'Bhanoday Vemula',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70867, pp. 833-845']},
#  '1170': {'aid': '1170',
#   'colls': 2,
#   'name': u'Anand Krishnamurthy',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48705 pp. 13-24; (12 pages)']},
#  '1179': {'aid': '1179',
#   'colls': 5,
#   'name': u'J. Corney',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84457 pp. 1283-1293; (11 pages)']},
#  '1178': {'aid': '1178',
#   'colls': 6,
#   'name': u'Jianxin (Roger) Jiao',
#   'nicknames': [u'Jianxin Roger Jiao'],
#   'paper_ids': [u'DETC2013-13693, pp. V03BT03A023',
#    u'DETC2009-86673 pp. 1009-1018; (10 pages)']},
#  '511': {'aid': '511',
#   'colls': 2,
#   'name': u'Gordon R. Pennock',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48833 pp. 1213-1219; (7 pages)']},
#  '510': {'aid': '510',
#   'colls': 2,
#   'name': u'D. Reuben Haupt',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35489, pp. V02BT03A021']},
#  '513': {'aid': '513',
#   'colls': 5,
#   'name': u'Karl Reichard',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28573, pp. 879-889']},
#  '1285': {'aid': '1285',
#   'colls': 7,
#   'name': u'Fang Liu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70496, pp. 157-166',
#    u'DETC2010-28618, pp. 479-486']},
#  '1284': {'aid': '1284',
#   'colls': 6,
#   'name': u'Jesse Schultz',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48000, pp. 955-965']},
#  '1287': {'aid': '1287',
#   'colls': 3,
#   'name': u'KyoungJong Park',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48060, pp. 1057-1066']},
#  '512': {'aid': '512',
#   'colls': 11,
#   'name': u'Richard Malak',
#   'nicknames': [u'Richard J. Malak, Jr.'],
#   'paper_ids': [u'DETC2012-70465, pp. 777-788',
#    u'DETC2011-48435, pp. 741-751',
#    u'DETC2014-34707, pp. V02BT03A010',
#    u'DETC2012-70551, pp. 1187-1199']},
#  '1281': {'aid': '1281',
#   'colls': 5,
#   'name': u'Pradeep George',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85469 pp. 799-806; (8 pages)',
#    u'DETC2006-99748 pp. 309-316; (8 pages)']},
#  '1280': {'aid': '1280',
#   'colls': 9,
#   'name': u'Yuan Mao Huang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34918 pp. 325-334; (10 pages)',
#    u'DETC2006-99425 pp. 189-198; (10 pages)',
#    u'DETC2004-57593 pp. 1111-1119; (9 pages)',
#    u'DETC2002/DAC-34062 pp. 243-249; (7 pages)',
#    u'DETC2003/DAC-48771 pp. 649-658; (10 pages)']},
#  '1283': {'aid': '1283',
#   'colls': 5,
#   'name': u'Margaret Strumolo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46610, pp. V02BT03A043']},
#  '1282': {'aid': '1282',
#   'colls': 4,
#   'name': u'Wanliang Wang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34044 pp. 109-113; (5 pages)']},
#  '1003': {'aid': '1003',
#   'colls': 21,
#   'name': u'Olivier de Weck',
#   'nicknames': [u'Olivier L. de Weck'],
#   'paper_ids': [u'DETC2006-99229 pp. 801-810; (10 pages)',
#    u'DETC2006-99163 pp. 783-799; (17 pages)',
#    u'DETC2007-35745 pp. 249-263; (15 pages)',
#    u'DETC2013-12013, pp. V03AT03A044',
#    u'DETC2015-46657, pp. V02AT03A035',
#    u'DETC2003/DAC-48721 pp. 175-185; (11 pages)']},
#  '1289': {'aid': '1289',
#   'colls': 4,
#   'name': u'Edoardo F. Colombo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46657, pp. V02AT03A035']},
#  '1288': {'aid': '1288',
#   'colls': 48,
#   'name': u'Zhimin Xi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71111, pp. 1249-1260',
#    u'DETC2011-48319, pp. 133-144',
#    u'DETC2010-29183, pp. 1133-1148',
#    u'DETC2013-13592, pp. V03AT03A039',
#    u'DETC2007-35619 pp. 1309-1320; (12 pages)',
#    u'DETC2008-49481 pp. 245-258; (14 pages)',
#    u'DETC2007-35601 pp. 1285-1295; (11 pages)',
#    u'DETC2009-87571 pp. 1229-1238; (10 pages)',
#    u'DETC2012-71105, pp. 361-368',
#    u'DETC2008-49663 pp. 259-272; (14 pages)',
#    u'DETC2014-35005, pp. V02AT03A044',
#    u'DETC2007-35614 pp. 1297-1308; (12 pages)',
#    u'DETC2007-35608 pp. 787-797; (11 pages)',
#    u'DETC2015-46938, pp. V02BT03A056',
#    u'DETC2015-46932, pp. V02AT03A037',
#    u'DETC2015-46935, pp. V02AT03A038']},
#  '514': {'aid': '514',
#   'colls': 12,
#   'name': u'W. Ross Morrow',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71176, pp. 405-422',
#    u'DETC2012-71201, pp. 423-441',
#    u'DETC2014-34493, pp. V02AT03A029',
#    u'DETC2013-13372, pp. V03AT03A033']},
#  '1579': {'aid': '1579',
#   'colls': 5,
#   'name': u'Sajad Arabnejad Khanoki',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47983, pp. 945-954',
#    u'DETC2011-47487, pp. 935-944']},
#  '1578': {'aid': '1578',
#   'colls': 2,
#   'name': u'Julie S. Linsey',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48404, pp. 509-520']},
#  '689': {'aid': '689',
#   'colls': 8,
#   'name': u'Masayuki Nakao',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57576 pp. 1095-1100; (6 pages)',
#    u'DETC2005-84543 pp. 225-230; (6 pages)']},
#  '688': {'aid': '688',
#   'colls': 5,
#   'name': u'Fenfen Xiong',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87430 pp. 1205-1215; (11 pages)']},
#  '685': {'aid': '685',
#   'colls': 2,
#   'name': u'Tsuyoshi Koga',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99377 pp. 173-187; (15 pages)']},
#  '684': {'aid': '684',
#   'colls': 4,
#   'name': u'Tomoyuki Hiroyasu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34059 pp. 217-223; (7 pages)']},
#  '687': {'aid': '687',
#   'colls': 6,
#   'name': u'S. Barbat',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49669 pp. 1275-1286; (12 pages)']},
#  '686': {'aid': '686',
#   'colls': 4,
#   'name': u'Jonathon Schuh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46832, pp. V02BT03A024']},
#  '681': {'aid': '681',
#   'colls': 3,
#   'name': u'Charlie C. L. Wang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35010 pp. 849-858; (10 pages)']},
#  '680': {'aid': '680',
#   'colls': 5,
#   'name': u'Danny A. Hlavinka',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49953 pp. 737-747; (11 pages)']},
#  '683': {'aid': '683',
#   'colls': 8,
#   'name': u'Francesco Iorio',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47541, pp. V02AT03A013',
#    u'DETC2015-47383, pp. V02AT03A012']},
#  '682': {'aid': '682',
#   'colls': 3,
#   'name': u'Feng Gao',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86807 pp. 629-635; (7 pages)']},
#  '623': {'aid': '623',
#   'colls': 6,
#   'name': u'Min-Yeong Moon',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46982, pp. V02BT03A057']},
#  '1226': {'aid': '1226',
#   'colls': 3,
#   'name': u'J. P. Jarrett',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12146, pp. V03BT03A030']},
#  '621': {'aid': '621',
#   'colls': 4,
#   'name': u'Surya Swamy',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35409 pp. 197-206; (10 pages)']},
#  '873': {'aid': '873',
#   'colls': 8,
#   'name': u'Gene Wiggs',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85406 pp. 785-798; (14 pages)',
#    u'DETC2008-49994 pp. 873-882; (10 pages)']},
#  '1224': {'aid': '1224',
#   'colls': 5,
#   'name': u'Melani Sullivan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46964, pp. V02AT03A039']},
#  '1223': {'aid': '1223',
#   'colls': 9,
#   'name': u'Atsuro Iga',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86618 pp. 1279-1286; (8 pages)',
#    u'DETC2008-49098 pp. 1157-1166; (10 pages)']},
#  '1222': {'aid': '1222',
#   'colls': 5,
#   'name': u'J\xfcrgen Gr\xe4sel',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57467 pp. 907-914; (8 pages)']},
#  '1221': {'aid': '1221',
#   'colls': 6,
#   'name': u'Alice Agogino',
#   'nicknames': [u'Alice M. Agogino'],
#   'paper_ids': [u'DETC2002/DAC-34065 pp. 267-273; (7 pages)',
#    u'DETC2004-57462 pp. 875-883; (9 pages)']},
#  '407': {'aid': '407',
#   'colls': 13,
#   'name': u'Natasha C. Wright',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35176, pp. V02AT03A026',
#    u'DETC2015-46521, pp. V02AT03A043',
#    u'DETC2015-47613, pp. V02AT03A046']},
#  '1370': {'aid': '1370',
#   'colls': 6,
#   'name': u'William R. Ledoux',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34703 pp. 501-513; (13 pages)']},
#  '1373': {'aid': '1373',
#   'colls': 5,
#   'name': u'Aaron Bobuk',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28573, pp. 879-889']},
#  '1372': {'aid': '1372',
#   'colls': 2,
#   'name': u'Robert Paasch',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48796 pp. 891-899; (9 pages)']},
#  '1375': {'aid': '1375',
#   'colls': 5,
#   'name': u'T. Wiegers',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48727 pp. 237-245; (9 pages)']},
#  '1374': {'aid': '1374',
#   'colls': 25,
#   'name': u'Po Ting Lin',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46130, pp. V02BT03A048',
#    u'DETC2010-28871, pp. 1099-1107',
#    u'DETC2011-48614, pp. 915-924',
#    u'DETC2014-34652, pp. V02BT03A028',
#    u'DETC2008-50054 pp. 757-766; (10 pages)',
#    u'DETC2009-87804 pp. 1251-1259; (9 pages)',
#    u'DETC2014-34636, pp. V02AT03A042',
#    u'DETC2012-70869, pp. 789-798']},
#  '1377': {'aid': '1377',
#   'colls': 4,
#   'name': u'Mark Snider',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99676 pp. 371-380; (10 pages)']},
#  '400': {'aid': '400',
#   'colls': 3,
#   'name': u'Karim A. Aguib',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49659 pp. 671-682; (12 pages)']},
#  '1379': {'aid': '1379',
#   'colls': 2,
#   'name': u'Kurt Hacker',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34108 pp. 703-712; (10 pages)']},
#  '1378': {'aid': '1378',
#   'colls': 2,
#   'name': u'Lauren S. Perry',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48815 pp. 1059-1067; (9 pages)']},
#  '1342': {'aid': '1342',
#   'colls': 8,
#   'name': u'S. M. Mahbub Murshed',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86739 pp. 615-628; (14 pages)',
#    u'DETC2007-35723 pp. 869-881; (13 pages)']},
#  '409': {'aid': '409',
#   'colls': 2,
#   'name': u'Ye Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70210, pp. 585-592']},
#  '408': {'aid': '408',
#   'colls': 2,
#   'name': u'Zhi Han',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48521, pp. 903-913']},
#  '453': {'aid': '453',
#   'colls': 3,
#   'name': u'Xuesong Mei',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34769 pp. 101-110; (10 pages)']},
#  '454': {'aid': '454',
#   'colls': 3,
#   'name': u'Margherita Peruzzini',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86228 pp. 1325-1339; (15 pages)']},
#  '2148': {'aid': '2148',
#   'colls': 2,
#   'name': u'Armand D. Assadi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57533 pp. 1059-1070; (12 pages)']},
#  '455': {'aid': '455',
#   'colls': 2,
#   'name': u'Sandipan Bandyopadhyay',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48819 pp. 1095-1106; (12 pages)']},
#  '1346': {'aid': '1346',
#   'colls': 2,
#   'name': u'Tetsuzo Kuragano',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34597 pp. 459-468; (10 pages)']},
#  '1347': {'aid': '1347',
#   'colls': 9,
#   'name': u'Ayman Youssef',
#   'nicknames': [u'Ayman M. A. Youssef'],
#   'paper_ids': [u'DETC2010-28389, pp. 1161-1169',
#    u'DETC2010-28849, pp. 849-856',
#    u'DETC2007-34970 pp. 839-848; (10 pages)']},
#  '1245': {'aid': '1245',
#   'colls': 4,
#   'name': u'Uwe Hinze',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34112 pp. 737-743; (7 pages)']},
#  '379': {'aid': '379',
#   'colls': 3,
#   'name': u'Yiben Lin',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85490 pp. 1273-1281; (9 pages)']},
#  '378': {'aid': '378',
#   'colls': 5,
#   'name': u'Minting Xiao',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12764, pp. V03AT03A022']},
#  '371': {'aid': '371',
#   'colls': 5,
#   'name': u'J. B. C. Davies',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84457 pp. 1283-1293; (11 pages)']},
#  '370': {'aid': '370',
#   'colls': 9,
#   'name': u'Eric Bibeau',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47960, pp. 315-324',
#    u'DETC2008-49991 pp. 531-541; (11 pages)']},
#  '373': {'aid': '373',
#   'colls': 3,
#   'name': u'Junheung Park',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46236, pp. V02AT03A005']},
#  '372': {'aid': '372',
#   'colls': 9,
#   'name': u'Saraj Gupta',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35672 pp. 1029-1038; (10 pages)',
#    u'DETC2009-87688 pp. 351-359; (9 pages)',
#    u'DETC2008-50050 pp. 83-91; (9 pages)']},
#  '375': {'aid': '375',
#   'colls': 6,
#   'name': u'M. Kokkolaras',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49669 pp. 1275-1286; (12 pages)']},
#  '374': {'aid': '374',
#   'colls': 3,
#   'name': u'Geraint Wyn Owen',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99581 pp. 241-248; (8 pages)']},
#  '377': {'aid': '377',
#   'colls': 4,
#   'name': u'Sang Bum Kim',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87571 pp. 1229-1238; (10 pages)']},
#  '376': {'aid': '376',
#   'colls': 5,
#   'name': u'Chi Zhou',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86268 pp. 543-557; (15 pages)',
#    u'DETC2010-28922, pp. 439-449']},
#  '393': {'aid': '393',
#   'colls': 3,
#   'name': u'Yuko Shimomura',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48789 pp. 833-841; (9 pages)']},
#  '392': {'aid': '392',
#   'colls': 5,
#   'name': u'Alberto Vergnano',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48390, pp. 997-1006']},
#  '391': {'aid': '391',
#   'colls': 4,
#   'name': u'Brian Peterson',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48754 pp. 495-502; (8 pages)']},
#  '390': {'aid': '390',
#   'colls': 4,
#   'name': u'Brian J. Daniels',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57229 pp. 369-378; (10 pages)']},
#  '397': {'aid': '397',
#   'colls': 9,
#   'name': u'Joung Taek Yoon',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34837, pp. V02AT03A043',
#    u'DETC2012-70529, pp. 333-347']},
#  '396': {'aid': '396',
#   'colls': 7,
#   'name': u'Warren P. Seering',
#   'nicknames': [u'Warren Seering'],
#   'paper_ids': [u'DETC2012-70521, pp. 479-484',
#    u'DETC2010-28539, pp. 1033-1041']},
#  '395': {'aid': '395',
#   'colls': 4,
#   'name': u'Kazuhiro Aoyama',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71305, pp. 141-150',
#    u'DETC2006-99377 pp. 173-187; (15 pages)']},
#  '394': {'aid': '394',
#   'colls': 3,
#   'name': u'Julian Booker',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34435 pp. 1093-1102; (10 pages)']},
#  '399': {'aid': '399',
#   'colls': 4,
#   'name': u'Niranjan Thyagaraja',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48532, pp. 33-42']},
#  '398': {'aid': '398',
#   'colls': 3,
#   'name': u'Sigurjon N. Kjaernested',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47766, pp. 543-552']},
#  '2309': {'aid': '2309',
#   'colls': 3,
#   'name': u'Charles D. Wood',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71171, pp. 455-462']},
#  '2308': {'aid': '2308',
#   'colls': 3,
#   'name': u'Rachel Hannah',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49976 pp. 231-243; (13 pages)']},
#  '2301': {'aid': '2301',
#   'colls': 3,
#   'name': u'Weigang An',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13348, pp. V03AT03A057']},
#  '2300': {'aid': '2300',
#   'colls': 6,
#   'name': u'Emad Samadiani',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99492 pp. 529-543; (15 pages)']},
#  '2303': {'aid': '2303',
#   'colls': 4,
#   'name': u'Daqing Zhang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86673 pp. 1009-1018; (10 pages)']},
#  '2302': {'aid': '2302',
#   'colls': 3,
#   'name': u'Chiradeep Sen',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87600 pp. 337-349; (13 pages)']},
#  '2305': {'aid': '2305',
#   'colls': 4,
#   'name': u'Warren Smith',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46457, pp. V02AT03A015']},
#  '2304': {'aid': '2304',
#   'colls': 5,
#   'name': u'Ayman Wasfy',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35723 pp. 869-881; (13 pages)']},
#  '2306': {'aid': '2306',
#   'colls': 2,
#   'name': u'Huai-Wei Ren',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49700 pp. 151-161; (11 pages)']},
#  '245': {'aid': '245',
#   'colls': 3,
#   'name': u'Yuming Qiu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99159 pp. 83-93; (11 pages)']},
#  '244': {'aid': '244',
#   'colls': 6,
#   'name': u'Robert Bj\xe4rnemo',
#   'nicknames': [u'Robert Bja\u0308rnemo'],
#   'paper_ids': [u'DETC2013-12886, pp. V03AT03A029',
#    u'DETC2011-47057, pp. 521-531']},
#  '247': {'aid': '247',
#   'colls': 11,
#   'name': u'Adel Younis',
#   'nicknames': [u'Adel A. Younis'],
#   'paper_ids': [u'DETC2013-12665, pp. V03BT03A013',
#    u'DETC2007-34839 pp. 273-283; (11 pages)',
#    u'DETC2013-12664, pp. V03BT03A012']},
#  '246': {'aid': '246',
#   'colls': 3,
#   'name': u'Oyku Asikoglu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34555, pp. V02BT03A038']},
#  '241': {'aid': '241',
#   'colls': 6,
#   'name': u'S. Y. Cheing',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57332 pp. 553-564; (12 pages)',
#    u'DETC2004-57331 pp. 541-552; (12 pages)']},
#  '240': {'aid': '240',
#   'colls': 2,
#   'name': u'Magnus Hofwing',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86454 pp. 1081-1091; (11 pages)']},
#  '243': {'aid': '243',
#   'colls': 5,
#   'name': u'Taylor Ferguson',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47640, pp. V02BT03A022']},
#  '242': {'aid': '242',
#   'colls': 3,
#   'name': u'Jasbir Arora',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71166, pp. 661-671']},
#  '249': {'aid': '249',
#   'colls': 2,
#   'name': u'Robert C. Fromuth',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-50091 pp. 581-588; (8 pages)']},
#  '248': {'aid': '248',
#   'colls': 5,
#   'name': u'Anoop A. Mullur',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85147 pp. 199-211; (13 pages)',
#    u'DETC2005-85041 pp. 743-757; (15 pages)']},
#  '2275': {'aid': '2275',
#   'colls': 3,
#   'name': u'Gordon M. Kaufman',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34926 pp. 285-295; (11 pages)']},
#  '2274': {'aid': '2274',
#   'colls': 4,
#   'name': u'Sree Shankar Satheesh Babu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34065, pp. V02AT03A005']},
#  '2277': {'aid': '2277',
#   'colls': 4,
#   'name': u'Jie Sheng',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48710 pp. 63-72; (10 pages)']},
#  '2276': {'aid': '2276',
#   'colls': 4,
#   'name': u'Huade Tan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28110, pp. 1149-1159']},
#  '2271': {'aid': '2271',
#   'colls': 3,
#   'name': u'Braden J. Hancock',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71039, pp. 799-812']},
#  '2270': {'aid': '2270',
#   'colls': 7,
#   'name': u'Ping An Du',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48525, pp. 25-32',
#    u'DETC2011-48710, pp. 1223-1229']},
#  '2273': {'aid': '2273',
#   'colls': 5,
#   'name': u'Lv Wang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34594, pp. V02BT03A022']},
#  '2272': {'aid': '2272',
#   'colls': 4,
#   'name': u'Hideki Aoyama',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84955 pp. 5-12; (8 pages)',
#    u'DETC2006-99331 pp. 1255-1262; (8 pages)']},
#  '2279': {'aid': '2279',
#   'colls': 19,
#   'name': u'Wei Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34708, pp. V02BT03A029',
#    u'DETC2009-86882 pp. 891-898; (8 pages)',
#    u'DETC2005-85125 pp. 13-23; (11 pages)',
#    u'DETC2015-47541, pp. V02AT03A013',
#    u'DETC2006-99312 pp. 31-41; (11 pages)',
#    u'DETC2015-47383, pp. V02AT03A012']},
#  '2278': {'aid': '2278',
#   'colls': 2,
#   'name': u'Abhinav Krishna Choudhary',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28775, pp. 151-166']},
#  '2459': {'aid': '2459',
#   'colls': 4,
#   'name': u'Tzu-Chieh Hung',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28140, pp. 941-952',
#    u'DETC2014-34471, pp. V02AT03A019']},
#  '2458': {'aid': '2458',
#   'colls': 6,
#   'name': u'Zachary Fisher',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47786, pp. V02BT03A042']},
#  '2455': {'aid': '2455',
#   'colls': 10,
#   'name': u'George Papakonstantopoulos',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70668, pp. 199-208']},
#  '2454': {'aid': '2454',
#   'colls': 4,
#   'name': u'Fabio Bruno',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49857 pp. 1227-1234; (8 pages)']},
#  '2457': {'aid': '2457',
#   'colls': 4,
#   'name': u'Christoph Ertelt',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49856 pp. 25-34; (10 pages)',
#    u'DETC2009-86827 pp. 651-660; (10 pages)']},
#  '2451': {'aid': '2451',
#   'colls': 6,
#   'name': u'Lucas A. Shaw',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46638, pp. V02BT03A005']},
#  '2450': {'aid': '2450',
#   'colls': 11,
#   'name': u'Ali Mehmani',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35358, pp. V02BT03A026',
#    u'DETC2013-13196, pp. V03AT03A024',
#    u'DETC2015-47188, pp. V02BT03A025']},
#  '2453': {'aid': '2453',
#   'colls': 2,
#   'name': u'T. C. Kingsley',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57328 pp. 529-540; (12 pages)']},
#  '2452': {'aid': '2452',
#   'colls': 4,
#   'name': u'Guoxian Zhang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34104 pp. 663-669; (7 pages)']},
#  '179': {'aid': '179',
#   'colls': 42,
#   'name': u'Frank W. Liou',
#   'nicknames': [u'Fuewen Frank Liou'],
#   'paper_ids': [u'DETC2012-70247, pp. 189-198',
#    u'DETC2011-47908, pp. 667-674',
#    u'DETC2015-46493, pp. V02AT03A016',
#    u'DETC2007-34445 pp. 413-419; (7 pages)',
#    u'DETC2008-50062 pp. 597-603; (7 pages)',
#    u'DETC2009-87335 pp. 579-586; (8 pages)',
#    u'DETC2010-28442, pp. 425-432',
#    u'DETC2006-99326 pp. 967-973; (7 pages)',
#    u'DETC2009-87370 pp. 587-596; (10 pages)',
#    u'DETC2004-57049 pp. 21-27; (7 pages)',
#    u'DETC2010-28440, pp. 415-423']},
#  '178': {'aid': '178',
#   'colls': 4,
#   'name': u'Yinghong Peng',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46373, pp. V02AT03A006']},
#  '177': {'aid': '177',
#   'colls': 4,
#   'name': u'Amy E. Wood',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35357, pp. V02AT03A047',
#    u'DETC2013-13108, pp. V03AT03A041']},
#  '176': {'aid': '176',
#   'colls': 7,
#   'name': u'Thomas Stone',
#   'nicknames': [u'Thomas M. Stone'],
#   'paper_ids': [u'DETC2014-34424, pp. V02AT03A009',
#    u'DETC2013-13228, pp. V03AT03A031',
#    u'DETC2012-71318, pp. 179-188']},
#  '175': {'aid': '175',
#   'colls': 9,
#   'name': u'Zhen Gao',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86259 pp. 815-826; (12 pages)',
#    u'DETC2008-49558 pp. 767-775; (9 pages)',
#    u'DETC2008-49188 pp. 719-726; (8 pages)']},
#  '174': {'aid': '174',
#   'colls': 6,
#   'name': u'Shashi K. Shahi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47960, pp. 315-324',
#    u'DETC2010-28972, pp. 701-713']},
#  '173': {'aid': '173',
#   'colls': 4,
#   'name': u'Jason Denhart',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13222, pp. V03BT03A038']},
#  '172': {'aid': '172',
#   'colls': 14,
#   'name': u'Ying Xiong',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35782 pp. 699-708; (10 pages)',
#    u'DETC2006-99599 pp. 1205-1214; (10 pages)',
#    u'DETC2009-87430 pp. 1205-1215; (11 pages)',
#    u'DETC2004-57418 pp. 749-765; (17 pages)']},
#  '171': {'aid': '171',
#   'colls': 4,
#   'name': u'Q. Z. Yang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84240 pp. 51-58; (8 pages)',
#    u'DETC2004-57522 pp. 1011-1019; (9 pages)']},
#  '170': {'aid': '170',
#   'colls': 5,
#   'name': u'Huaicai Mo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34102 pp. 647-653; (7 pages)']},
#  '2051': {'aid': '2051',
#   'colls': 2,
#   'name': u'Haoyu Wang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85546 pp. 141-154; (14 pages)']},
#  '2050': {'aid': '2050',
#   'colls': 2,
#   'name': u'Aki M. Mikkola',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34094 pp. 559-566; (8 pages)']},
#  '2053': {'aid': '2053',
#   'colls': 5,
#   'name': u'St\xe9phane Guillet',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48777 pp. 711-720; (10 pages)']},
#  '2052': {'aid': '2052',
#   'colls': 11,
#   'name': u'Yoshiki Shimomura',
# ...
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28549, pp. 35-41']},
#  '2140': {'aid': '2140',
#   'colls': 11,
#   'name': u'Jian Tu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57404 pp. 719-727; (9 pages)',
#    u'DETC2004-57255 pp. 419-430; (12 pages)',
#    u'DETC2003/DAC-48708 pp. 45-54; (10 pages)']},
#  '920': {'aid': '920',
#   'colls': 2,
#   'name': u'Sherif Aly',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48798 pp. 907-915; (9 pages)']},
#  '921': {'aid': '921',
#   'colls': 7,
#   'name': u'Sudhakar Teegavarapu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99676 pp. 371-380; (10 pages)',
#    u'DETC2006-99678 pp. 73-82; (10 pages)']},
#  '922': {'aid': '922',
#   'colls': 6,
#   'name': u'Mustafa H. Arafa',
#   'nicknames': [u'Mustafa Arafa'],
#   'paper_ids': [u'DETC2008-49727 pp. 521-530; (10 pages)',
#    u'DETC2010-28389, pp. 1161-1169']},
#  '923': {'aid': '923',
#   'colls': 4,
#   'name': u'Wei Jin',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34260 pp. 1083-1092; (10 pages)']},
#  '924': {'aid': '924',
#   'colls': 3,
#   'name': u'Gordon Warn',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46895, pp. V02BT03A033']},
#  '925': {'aid': '925',
#   'colls': 2,
#   'name': u'Jigar Vadia',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48823 pp. 1135-1142; (8 pages)']},
#  '2149': {'aid': '2149',
#   'colls': 2,
#   'name': u'Venketesh N. Dubey',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48812 pp. 1033-1039; (7 pages)']},
#  '927': {'aid': '927',
#   'colls': 5,
#   'name': u'Zhaoqian Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49871 pp. 961-968; (8 pages)']},
#  '1920': {'aid': '1920',
#   'colls': 2,
#   'name': u'Palwinder Singh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48783 pp. 775-784; (10 pages)']},
#  '1921': {'aid': '1921',
#   'colls': 4,
#   'name': u'Nengsheng Bao',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49230 pp. 553-559; (7 pages)']},
#  '1922': {'aid': '1922',
#   'colls': 21,
#   'name': u'Soundar R. T. Kumara',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99287 pp. 317-325; (9 pages)',
#    u'DETC2009-86899 pp. 101-110; (10 pages)',
#    u'DETC2007-34687 pp. 591-600; (10 pages)',
#    u'DETC2009-87280 pp. 1019-1027; (9 pages)',
#    u'DETC2008-49683 pp. 1053-1066; (14 pages)',
#    u'DETC2004-57430 pp. 781-790; (10 pages)']},
#  '1923': {'aid': '1923',
#   'colls': 3,
#   'name': u'Behzad Esmaeilian',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46864, pp. V02AT03A019']},
#  '1924': {'aid': '1924',
#   'colls': 2,
#   'name': u'Anand P. Deshmukh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12262, pp. V03BT03A011']},
#  '1925': {'aid': '1925',
#   'colls': 3,
#   'name': u'Byungchai Lee',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34581, pp. V02BT03A050']},
#  '1927': {'aid': '1927',
#   'colls': 3,
#   'name': u'Ardeshir Raihanian Mashhadi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46864, pp. V02AT03A019']},
#  '1928': {'aid': '1928',
#   'colls': 3,
#   'name': u'Jeffrey D. Wishart',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99606 pp. 757-772; (16 pages)']},
#  '832': {'aid': '832',
#   'colls': 3,
#   'name': u'Axel Reichwein',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87368 pp. 661-670; (10 pages)']},
#  '833': {'aid': '833',
#   'colls': 3,
#   'name': u'Vikas Tomar',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35913 pp. 39-49; (11 pages)']},
#  '830': {'aid': '830',
#   'colls': 32,
#   'name': u'Maria Yang',
#   'nicknames': [u'Maria C. Yang'],
#   'paper_ids': [u'DETC2014-34491, pp. V02AT03A010',
#    u'DETC2011-48749, pp. 231-240',
#    u'DETC2012-70521, pp. 479-484',
#    u'DETC2012-70468, pp. 379-390',
#    u'DETC2015-47667, pp. V02AT03A023',
#    u'DETC2014-35032, pp. V02AT03A024',
#    u'DETC2011-48680, pp. 717-726',
#    u'DETC2013-12514, pp. V03AT03A035']},
#  '831': {'aid': '831',
#   'colls': 2,
#   'name': u'Alba Perez',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48818 pp. 1087-1094; (8 pages)']},
#  '836': {'aid': '836',
#   'colls': 4,
#   'name': u'Xu Zhang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13550, pp. V03BT03A010']},
#  '834': {'aid': '834',
#   'colls': 7,
#   'name': u'G. J. Park',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84794 pp. 627-636; (10 pages)',
#    u'DETC2005-84555 pp. 231-241; (11 pages)']},
#  '835': {'aid': '835',
#   'colls': 4,
#   'name': u'Yu-Chung Liao',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99425 pp. 189-198; (10 pages)',
#    u'DETC2004-57593 pp. 1111-1119; (9 pages)']},
#  '838': {'aid': '838',
#   'colls': 3,
#   'name': u'Ramesh Rebba',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28343, pp. 997-1005']},
#  '839': {'aid': '839',
#   'colls': 4,
#   'name': u'Prakhar Jaiswal',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34065, pp. V02AT03A005']},
#  '3': {'aid': '3',
#   'colls': 39,
#   'name': u'James Allison',
#   'nicknames': [u'James T. Allison'],
#   'paper_ids': [u'DETC2005-84790 pp. 265-275; (11 pages)',
#    u'DETC2015-46832, pp. V02BT03A024',
#    u'DETC2008-49823 pp. 917-926; (10 pages)',
#    u'DETC2013-13462, pp. V03AT03A058',
#    u'DETC2013-12600, pp. V03AT03A018',
#    u'DETC2007-34698 pp. 709-718; (10 pages)',
#    u'DETC2014-34256, pp. V02AT03A006',
#    u'DETC2013-12262, pp. V03BT03A011',
#    u'DETC2010-29055, pp. 715-728',
#    u'DETC2010-28788, pp. 755-764',
#    u'DETC2015-46768, pp. V02BT03A008',
#    u'DETC2014-35314, pp. V02BT03A039',
#    u'DETC2011-48521, pp. 903-913',
#    u'DETC2012-71108, pp. 847-856',
#    u'DETC2010-28887, pp. 765-774']},
#  '1987': {'aid': '1987',
#   'colls': 4,
#   'name': u'Beno\xeet Gu\xe9das',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70640, pp. 727-734']},
#  '1532': {'aid': '1532',
#   'colls': 3,
#   'name': u'Roy Awedikian',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49439 pp. 15-24; (10 pages)']},
#  '784': {'aid': '784',
#   'colls': 6,
#   'name': u'Abhijit K. Choudhury',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99573 pp. 937-949; (13 pages)']},
#  '785': {'aid': '785',
#   'colls': 14,
#   'name': u'Takeshi Kishinami',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34052 pp. 161-168; (8 pages)',
#    u'DETC2004-57086 pp. 85-91; (7 pages)',
#    u'DETC2007-35171 pp. 547-556; (10 pages)']},
#  '786': {'aid': '786',
#   'colls': 13,
#   'name': u'Shapour Azarm',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99316 pp. 405-414; (10 pages)',
#    u'DETC2007-34818 pp. 719-729; (11 pages)',
#    u'DETC2002/DAC-34122 pp. 829-838; (10 pages)',
#    u'DETC2005-85095 pp. 1233-1242; (10 pages)',
#    u'DETC2014-34699, pp. V02AT03A031']},
#  '787': {'aid': '787',
#   'colls': 2,
#   'name': u'Chun-Min Ho',
#   'nicknames': [],
#   'paper_ids': [u'DETC2010-28159, pp. 953-962']},
#  '780': {'aid': '780',
#   'colls': 5,
#   'name': u'Marcello Pellicciari',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48390, pp. 997-1006']},
#  '781': {'aid': '781',
#   'colls': 5,
#   'name': u'Hoda Mehrpouyan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13248, pp. V03AT03A048']},
#  '782': {'aid': '782',
#   'colls': 5,
#   'name': u'Jingjun Yu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48820 pp. 1107-1115; (9 pages)']},
#  '1729': {'aid': '1729',
#   'colls': 3,
#   'name': u'Robert D. Campbell',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48584, pp. 453-460']},
#  '1726': {'aid': '1726',
#   'colls': 6,
#   'name': u'Sheng Q. Xie',
#   'nicknames': [],
#   'paper_ids': [u'DETC2008-49725 pp. 589-596; (8 pages)']},
#  '1727': {'aid': '1727',
#   'colls': 3,
#   'name': u'Nina P. Robson',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13700, pp. V03BT03A024']},
#  '1724': {'aid': '1724',
#   'colls': 4,
#   'name': u'L. Wang',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48338, pp. 405-419']},
#  '1725': {'aid': '1725',
#   'colls': 6,
#   'name': u'Fred M. Feinberg',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-35270, pp. V02AT03A035',
#    u'DETC2015-46491, pp. V02AT03A034']},
#  '788': {'aid': '788',
#   'colls': 6,
#   'name': u'Kurt A. Chipperfield',
#   'nicknames': [u'Kurt Chipperfield'],
#   'paper_ids': [u'DETC2002/DAC-34067 pp. 283-287; (5 pages)',
#    u'DETC2002/DAC-34152 pp. 1099-1103; (5 pages)',
#    u'DETC2005-84496 pp. 1295-1300; (6 pages)']},
#  '789': {'aid': '789',
#   'colls': 12,
#   'name': u'Jay D. Martin',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34662 pp. 663-673; (11 pages)',
#    u'DETC2008-49684 pp. 511-520; (10 pages)',
#    u'DETC2003/DAC-48762 pp. 567-576; (10 pages)',
#    u'DETC2005-84984 pp. 1183-1193; (11 pages)',
#    u'DETC2011-48579, pp. 763-773',
#    u'DETC2004-57300 pp. 481-492; (12 pages)']},
#  '1720': {'aid': '1720',
#   'colls': 5,
#   'name': u'Hee Soo Kim',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34837, pp. V02AT03A043']},
#  '1721': {'aid': '1721',
#   'colls': 6,
#   'name': u'George R. Farquar',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46638, pp. V02BT03A005']},
#  '252': {'aid': '252',
#   'colls': 3,
#   'name': u'G. Y. Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87121 pp. 751-765; (15 pages)']},
#  '2439': {'aid': '2439',
#   'colls': 2,
#   'name': u'Yonghong Peng',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57224 pp. 341-349; (9 pages)']},
#  '60': {'aid': '60',
#   'colls': 25,
#   'name': u'Mian Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99316 pp. 405-414; (10 pages)',
#    u'DETC2013-12293, pp. V03BT03A026',
#    u'DETC2015-47059, pp. V02AT03A011',
#    u'DETC2013-12235, pp. V03BT03A047',
#    u'DETC2014-34257, pp. V02BT03A042',
#    u'DETC2012-70139, pp. 1087-1100',
#    u'DETC2010-28543, pp. 825-836',
#    u'DETC2015-46307, pp. V02BT03A031',
#    u'DETC2007-34818 pp. 719-729; (11 pages)',
#    u'DETC2005-85095 pp. 1233-1242; (10 pages)',
#    u'DETC2014-34259, pp. V02BT03A043']},
#  '61': {'aid': '61',
#   'colls': 5,
#   'name': u'Francesco Leali',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48390, pp. 997-1006']},
#  '62': {'aid': '62',
#   'colls': 10,
#   'name': u'Yuji Kawaguchi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57370 pp. 665-674; (10 pages)']},
#  '152': {'aid': '152',
#   'colls': 4,
#   'name': u'Mathias Almer',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34151 pp. 1089-1098; (10 pages)']},
#  '64': {'aid': '64',
#   'colls': 4,
#   'name': u'Adam B. Cooper',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48734 pp. 307-318; (12 pages)']},
#  '65': {'aid': '65',
#   'colls': 8,
#   'name': u'Man-Hoi Koo',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-13304, pp. V03AT03A004']},
#  '66': {'aid': '66',
#   'colls': 6,
#   'name': u'Edgar Galvan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34707, pp. V02BT03A010',
#    u'DETC2012-70465, pp. 777-788']},
#  '67': {'aid': '67',
#   'colls': 3,
#   'name': u'Ali Saeed',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-84214 pp. 447-455; (9 pages)']},
#  '68': {'aid': '68',
#   'colls': 2,
#   'name': u'V. Sundararajan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87829 pp. 693-698; (6 pages)']},
#  '69': {'aid': '69',
#   'colls': 9,
#   'name': u'Farhad Ameri',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87600 pp. 337-349; (13 pages)',
#    u'DETC2006-99595 pp. 105-114; (10 pages)',
#    u'DETC2007-35610 pp. 581-590; (10 pages)']},
#  '1371': {'aid': '1371',
#   'colls': 6,
#   'name': u'Ulf Sellgren',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47181, pp. V02BT03A035',
#    u'DETC2013-13005, pp. V03BT03A032']},
#  '1588': {'aid': '1588',
#   'colls': 6,
#   'name': u'Shikui Chen',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-47518, pp. V02BT03A012',
#    u'DETC2009-87083 pp. 1295-1305; (11 pages)']},
#  '1589': {'aid': '1589',
#   'colls': 5,
#   'name': u'Youn Doh Ha',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47697, pp. 103-110']},
#  '406': {'aid': '406',
#   'colls': 6,
#   'name': u'Yangqiu Patrick Hu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34703 pp. 501-513; (13 pages)']},
#  '1582': {'aid': '1582',
#   'colls': 3,
#   'name': u'Russell R. Barton',
#   'nicknames': [],
#   'paper_ids': [u'DETC2003/DAC-48766 pp. 605-614; (10 pages)']},
#  '1583': {'aid': '1583',
#   'colls': 4,
#   'name': u'Zhengdong Ma',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47037, pp. 633-642']},
#  '1580': {'aid': '1580',
#   'colls': 3,
#   'name': u'M. A. Nahon',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34105 pp. 671-680; (10 pages)']},
#  '1581': {'aid': '1581',
#   'colls': 9,
#   'name': u'Sadao Nishiyama',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-34940 pp. 387-396; (10 pages)',
#    u'DETC2007-35637 pp. 405-411; (7 pages)']},
#  '1586': {'aid': '1586',
#   'colls': 47,
#   'name': u'K. K. Choi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2015-46982, pp. V02BT03A057',
#    u'DETC2008-49494 pp. 1145-1156; (12 pages)',
#    u'DETC2014-34644, pp. V02BT03A051',
#    u'DETC2005-85146 pp. 773-783; (11 pages)',
#    u'DETC2015-47359, pp. V02BT03A059',
#    u'DETC2012-70725, pp. 1227-1238',
#    u'DETC2011-47538, pp. 1139-1149',
#    u'DETC2009-87084 pp. 1171-1181; (11 pages)',
#    u'DETC2009-86701 pp. 1121-1136; (16 pages)',
#    u'DETC2015-47370, pp. V02BT03A060',
#    u'DETC2012-70715, pp. 1213-1225']},
#  '405': {'aid': '405',
#   'colls': 13,
#   'name': u'Kate S. Whitefoot',
#   'nicknames': [u'Katie Whitefoot'],
#   'paper_ids': [u'DETC2012-71201, pp. 423-441',
#    u'DETC2010-29055, pp. 715-728',
#    u'DETC2009-87165 pp. 397-406; (10 pages)',
#    u'DETC2011-48007, pp. 395-404']},
#  '1584': {'aid': '1584',
#   'colls': 2,
#   'name': u'Shiqiao Li',
#   'nicknames': [],
#   'paper_ids': [u'DETC2005-85431 pp. 543-553; (11 pages)']},
#  '1585': {'aid': '1585',
#   'colls': 4,
#   'name': u'Sravya Thoomu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86473 pp. 1093-1104; (12 pages)']},
#  '2433': {'aid': '2433',
#   'colls': 3,
#   'name': u'Guenter Conzelmann',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-48385, pp. 55-66']},
#  '404': {'aid': '404',
#   'colls': 15,
#   'name': u'Krishnan Suresh',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47329, pp. 805-813',
#    u'DETC2015-46349, pp. V02AT03A014',
#    u'DETC2006-99413 pp. 63-71; (9 pages)',
#    u'DETC2004-57096 pp. 101-107; (7 pages)',
#    u'DETC2007-35353 pp. 335-344; (10 pages)',
#    u'DETC2006-99612 pp. 575-586; (12 pages)',
#    u'DETC2010-28592, pp. 1191-1200']},
#  '508': {'aid': '508',
#   'colls': 2,
#   'name': u'Sagar Chowdhury',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-87304 pp. 973-985; (13 pages)']},
#  '509': {'aid': '509',
#   'colls': 8,
#   'name': u'Paul F. Egan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2013-12072, pp. V03AT03A045',
#    u'DETC2011-48568, pp. 1017-1025']},
#  '1032': {'aid': '1032',
#   'colls': 7,
#   'name': u'Danish Khan',
#   'nicknames': [],
#   'paper_ids': [u'DETC2014-34203, pp. V02BT03A004']},
#  '507': {'aid': '507',
#   'colls': 8,
#   'name': u'Alexandrea Chor',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70484, pp. 151-156']},
#  '504': {'aid': '504',
#   'colls': 2,
#   'name': u'Harsheel Shah',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47865, pp. 1161-1167']},
#  '505': {'aid': '505',
#   'colls': 3,
#   'name': u'Tomohiro Taguchi',
#   'nicknames': [],
#   'paper_ids': [u'DETC2006-99360 pp. 327-340; (14 pages)']},
#  '502': {'aid': '502',
#   'colls': 7,
#   'name': u'Matthias Messer',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35743 pp. 799-827; (29 pages)',
#    u'DETC2012-70345, pp. 1125-1141']},
#  '503': {'aid': '503',
#   'colls': 3,
#   'name': u'Jie Chen',
#   'nicknames': [],
#   'paper_ids': [u'DETC2009-86807 pp. 629-635; (7 pages)']},
#  '1034': {'aid': '1034',
#   'colls': 3,
#   'name': u'Yoon Young Kim',
#   'nicknames': [],
#   'paper_ids': [u'DETC2011-47341, pp. 93-101']},
#  '501': {'aid': '501',
#   'colls': 8,
#   'name': u'Karen J. Ostergaard',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57076 pp. 65-73; (9 pages)',
#    u'DETC2003/DAC-48781 pp. 755-764; (10 pages)',
#    u'DETC2003/DAC-48742 pp. 383-390; (8 pages)']},
#  '630': {'aid': '630',
#   'colls': 2,
#   'name': u'Yasushi Suehisa',
#   'nicknames': [],
#   'paper_ids': [u'DETC2007-35133 pp. 601-610; (10 pages)']},
#  '1213': {'aid': '1213',
#   'colls': 6,
#   'name': u'El-Sayed Aziz',
#   'nicknames': [],
#   'paper_ids': [u'DETC2002/DAC-34089 pp. 505-515; (11 pages)',
#    u'DETC2002/DAC-34114 pp. 753-763; (11 pages)',
#    u'DETC2004-57205 pp. 313-320; (8 pages)']},
#  '632': {'aid': '632',
#   'colls': 4,
#   'name': u'James Rankin, II',
#   'nicknames': [],
#   'paper_ids': [u'DETC2004-57156 pp. 209-214; (6 pages)']},
#  '633': {'aid': '633',
#   'colls': 2,
#   'name': u'Anil K. Annepu',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-70424, pp. 863-873']},
#  ...}

# %%
papers['DETC2002/DAC-34072 pp. 327-336; (10 pages)'].__dict__
# Out:
# {'abstract': u'In curve design, controlling the characteristics of the overall shape is difficult using conventional microscopic shape-information such as dimension. Curvature entropy as calculated by the distribution of curvature was proposed as the macroscopic shape-information, and was confirmed to represent the complexity of a shape. In order to adjust the shape recognition of human beings, a Markov process was introduced into the definition of the macroscopic shape-information. Shape-generation method using the macroscopic shape-information was developed, and was applied to the design of an automobile side-view. Thus, the possibility of curve design-support using the macroscopic shape-information was indicated.',
#  'author_ids': ['1093', '742'],
#  'author_names': [u'Yoshiki Ujiie', u'Yoshiyuki Matsuoka'],
#  'broad_topic': u'',
#  'citations': [],
#  'cited_by': [],
#  'detc': u'DETC2002',
#  'pid': u'DETC2002/DAC-34072 pp. 327-336; (10 pages)',
#  'title': u'Macroscopic Shape-Information as a Curve Design-Guideline',
#  'topics': [u'Design', u'Shapes'],
#  'url': u'http://proceedings.asmedigitalcollection.asme.org//proceeding.aspx?articleID=1579888',
#  'year': 2002}

# %%
G = nx.MultiGraph()

# %%
G.add_edge("1","2",weight=1)
G.add_edge("3","2",weight=0.3)
G.add_edge("1","2",weight=2)
G.add_edge("1","2",weight=1)

# %%
G.degree(weight='weight')
# Out:
# {'1': 4, '2': 4.3, '3': 0.3}

# %%
stats = {}
for p in papers.values():
    try:
        stats[p.year] +=1
    except:
        stats[p.year] =1
stats
# Out:
# {2002: 117,
#  2003: 143,
#  2004: 115,
#  2005: 128,
#  2006: 118,
#  2007: 125,
#  2008: 119,
#  2009: 122,
#  2010: 112,
#  2011: 110,
#  2012: 123,
#  2013: 114,
#  2014: 108,
#  2015: 114}

# %%
1668/14.
# Out:
# 119.14285714285714

# %%
len(authors)
# Out:
# 2370

# %% [markdown]
# # Network Construction

# %%
def make_pairs(input_list):
    length = len(input_list)
    ret = []
    if length == 1:
        return []
    for i in range(0, length-1):
        for j in range(i+1, length):
            ret.append((input_list[i], input_list[j]))
    return ret

def papers_by_year(papers, inf, sup):
    ret = []
    for p in papers.values():
        if p.year <= sup and p.year >= inf:
            ret.append(p)
    return ret

def make_edges(papers_selected):
    edge_list = []
    for p in papers_selected:
        edge_list.extend(make_pairs(p.author_ids))
    return edge_list

def author_network(papers, inf_year, sup_year):
    papers_between = papers_by_year(papers, inf_year, sup_year)
    edge_list = make_edges(papers_between)
    
    G=nx.Graph()
    for edge in edge_list:
        G.add_edge(edge[0], edge[1])
    return G

def multigraph_author_network(papers, inf_year, sup_year):
    papers_between = papers_by_year(papers, inf_year, sup_year)
    edge_list = make_edges(papers_between)
    
    G=nx.MultiGraph()
    for edge in edge_list:
        G.add_edge(edge[0], edge[1])
    return G

# %%
def weighted_author_network(papers, inf_year, sup_year):
    papers_between = papers_by_year(papers, inf_year, sup_year)
    edge_list = make_edges(papers_between)
    
    G=nx.MultiGraph()
    G=nx.Graph(G)
    for edge in edge_list:
        G.add_edge(edge[0], edge[1])
    return G

# %% [markdown]
# # Author Search

# %%
def author_search(authors, name):
    name_set = []
    for author in authors.values():
        name_set.append(author.name)
    candidates = process.extract(name, name_set, limit=2)
    
    result = {}
    for candidate in candidates:
        cur = candidate[0]
        for author in authors.values():
            if author.name == cur:
                result[author.aid] = author.__dict__
    return result

def display_author(authors, aid):
    return authors[aid].__dict__

# %%
author_search(authors, "james allison")
# Out:
# {'3': {'aid': '3',
#   'name': u'James Allison',
#   'nicknames': [u'James T. Allison'],
#   'paper_ids': [u'DETC2005-84790 pp. 265-275; (11 pages)',
#    u'DETC2015-46832, pp. V02BT03A024',
#    u'DETC2008-49823 pp. 917-926; (10 pages)',
#    u'DETC2013-13462, pp. V03AT03A058',
#    u'DETC2013-12600, pp. V03AT03A018',
#    u'DETC2007-34698 pp. 709-718; (10 pages)',
#    u'DETC2014-34256, pp. V02AT03A006',
#    u'DETC2013-12262, pp. V03BT03A011',
#    u'DETC2010-29055, pp. 715-728',
#    u'DETC2010-28788, pp. 755-764',
#    u'DETC2015-46768, pp. V02BT03A008',
#    u'DETC2014-35314, pp. V02BT03A039',
#    u'DETC2011-48521, pp. 903-913',
#    u'DETC2012-71108, pp. 847-856',
#    u'DETC2010-28887, pp. 765-774']},
#  '821': {'aid': '821',
#   'name': u'James P. Schmiedeler',
#   'nicknames': [],
#   'paper_ids': [u'DETC2012-71391, pp. 1281-1293']}}

# %%
def plot_time_series(data, ytext, xtext, filename, size, ylim = None, xlim = None):
    keys = data.keys()
    values = data.values()
    plt.figure(figsize=size)
    if ylim != None:
        plt.ylim(0, ylim)
        
    if xlim != None:
        plt.xlim(0, xlim)
        
    plt.plot(keys, values)
    for a,b in zip(keys, values): 
        plt.text(a, b, '%.2f' % b)
    plt.ylabel(ytext)
    plt.xlabel(xtext)
    
    plt.savefig('pp.png', format='png')
    plt.show()
    
    return None

def plot_time_series_2(data, ytext, xtext, filename, size, ymin, ymax):
    keys = data.keys()
    values = data.values()
    plt.figure(figsize=size)
    if ymin != None:
        plt.ylim(ymin, ymax)
        
        
    plt.plot(keys, values)
    for a,b in zip(keys, values): 
        plt.text(a, b, '%.2f' % b)
    plt.ylabel(ytext)
    plt.xlabel(xtext)
    
    plt.savefig('pp.png', format='png')
    plt.show()
    
    return None

# %% [markdown]
# # 1. Total papers

# %%
len(papers)
# Out:
# 1668

# %% [markdown]
# From 2002 to 2015, there are 1668 papers in DAC.

# %%
def year_paper_stats():
    stats = {}
    for p in papers.values():
        stats[p.year] = 0
        
    for p in papers.values():
        stats[p.year] += 1
    
    return stats

# %%
yt = year_paper_stats()
plt.plot(yt.keys(), yt.values())
plt.ylabel('Papers')
plt.xlabel('Year')

# %%
pd.DataFrame(yt.items(), columns=['Year', 'Papers'])
# Out:
#     Year  Papers
# 0   2002     117
# 1   2003     143
# 2   2004     115
# 3   2005     128
# 4   2006     118
# 5   2007     125
# 6   2008     119
# 7   2009     122
# 8   2010     112
# 9   2011     110
# 10  2012     123
# 11  2013     114
# 12  2014     108
# 13  2015     114

# %% [markdown]
# # 2. Total authors

# %%
len(authors)
# Out:
# 2370

# %% [markdown]
# From 2002 to 2015, there are 2374 authors in DAC.

# %%
def year_author_stats():
    year_au = {}
    for p in papers.values():
        year_au[p.year] = set()
        
    for p in papers.values():
        for au in p.author_ids:
            year_au[p.year].add(au)
    
    stats = {}
    for y in year_au.keys():
        stats[y] = len(year_au[y])
    return stats

# %%
yt = year_author_stats()
plt.plot(yt.keys(), yt.values())
plt.ylabel('Authors')
plt.xlabel('Year')

# %%
pd.DataFrame(yt.items(), columns=['Year', 'Authors'])
# Out:
#     Year  Authors
# 0   2002      278
# 1   2003      319
# 2   2004      275
# 3   2005      281
# 4   2006      272
# 5   2007      285
# 6   2008      308
# 7   2009      307
# 8   2010      273
# 9   2011      282
# 10  2012      302
# 11  2013      266
# 12  2014      269
# 13  2015      304

# %% [markdown]
# # 3. Mean papers per author

# %%
def avg_stats():
    stats = {}
    
    au_stats = year_author_stats()
    pp_stats = year_paper_stats()
    
    for year in au_stats.keys():
        stats[year] = float(pp_stats[year])/au_stats[year]
        
    return stats

# %%
yt = avg_stats()
plt.plot(yt.keys(), yt.values())
plt.ylabel('Mean papers per author')
plt.xlabel('Year')

# %%
pd.DataFrame(yt.items(), columns=['Year', 'Mean papers per author'])
# Out:
#     Year  Mean papers per author
# 0   2002                0.420863
# 1   2003                0.448276
# 2   2004                0.418182
# 3   2005                0.455516
# 4   2006                0.433824
# 5   2007                0.438596
# 6   2008                0.386364
# 7   2009                0.397394
# 8   2010                0.410256
# 9   2011                0.390071
# 10  2012                0.407285
# 11  2013                0.428571
# 12  2014                0.401487
# 13  2015                0.375000

# %% [markdown]
# # 4. Mean authors per paper

# %%
def avg_stats():
    stats = {}
    
    au_stats = year_author_stats()
    pp_stats = year_paper_stats()
    
    for year in au_stats.keys():
        stats[year] = float(au_stats[year])/float(pp_stats[year])
        
    return stats

# %%
yt = avg_stats()
plt.plot(yt.keys(), yt.values())
plt.ylabel('Mean authors per paper')
plt.xlabel('Year')

# %%
277/117.
# Out:
# 2.3675213675213675

# %%
pd.DataFrame(yt.items(), columns=['Year', 'Mean authors per paper'])
# Out:
#     Year  Mean authors per paper
# 0   2002                2.376068
# 1   2003                2.230769
# 2   2004                2.391304
# 3   2005                2.195312
# 4   2006                2.305085
# 5   2007                2.280000
# 6   2008                2.588235
# 7   2009                2.516393
# 8   2010                2.437500
# 9   2011                2.563636
# 10  2012                2.455285
# 11  2013                2.333333
# 12  2014                2.490741
# 13  2015                2.666667

# %%
plot_time_series(mean_au, "Average number of authors each paper", "Year","avgAuthorPaperYear", (8,5))

# %% [markdown]
# # 5. Average Degree

# %% [markdown]
# ## 4.1 degree

# %%
mean_degree = {}
for year in yt.keys():
    cur_graph = author_network(papers, 2002, year)
    dsum = float(sum(cur_graph.degree().values()))
    size = len(cur_graph.degree())
    mean_degree[year-2002] = dsum/size

# %%
plot_time_series(mean_degree, "Average Degree", "Number of years since 2002","avgDegYear", (8,5))

# %% [markdown]
# ## 4.2 weighted degree

# %%
mean_degree_per_paper = {}
for year in yt.keys():
    cur_graph = multigraph_author_network(papers, 2002, year)
    dsum = float(sum(cur_graph.degree().values()))
    size = len(cur_graph.degree())
    mean_degree_per_paper[year-2002] = dsum/size

# %%
plot_time_series(mean_degree_per_paper, "Average Degree (weighted)", "Number of years since 2002","avgDegYear", (8,5))

# %%
ytext, xtext = "Average Degree", "Number of Years since 2002"

data_1 = mean_degree_per_paper
data_2 = mean_degree_weight_per_paper

keys = data.keys()
values = data.values()
plt.figure(figsize=(8,5))
plt.plot(keys, values)
for a,b in zip(keys, values): 
    plt.text(a, b, '%.2f' % b)
plt.ylabel(ytext)
plt.xlabel(xtext)

plt.savefig('pp.png', format='png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d245b2b66a3d> in <module>()
#       2
#       3 data_1 = mean_degree_per_paper
# ----> 4 data_2 = mean_degree_weight_per_paper
#       5
#       6 keys = data.keys()
#
# NameError: name 'mean_degree_weight_per_paper' is not defined

# %% [markdown]
# # 5. Collaborators per author

# %%
g = author_network(papers, 0, 2015)

# %%
plt.hist(g.degree().values(), bins=200)
plt.title("DAC Network")
plt.xlabel("Number of collaborators")
plt.ylabel("Frequency")
plt.show()

# %%
degree_under_15 = [i for i in g.degree().values() if i <= 15]

# %%
plt.hist(degree_under_15, bins=30)
plt.title("DAC Network")
plt.xlabel("Number of collaborators")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # 6. Size of giant component

# %%
def size_of_giant_component(inf_year, sup_year):
    g = author_network(papers, inf_year, sup_year)
    cc = nx.connected_component_subgraphs(g)
    comps = [len(c) for c in sorted(nx.connected_components(g), key=len, reverse=True)]
    return comps[0]

# %%
size_of_giant_component(0, 2015)
# Out:
# 1191

# %%
for year in range(2002, 2016):
    print year, size_of_giant_component(year, year)
# Out:
# 2002 9
# 2003 17
# 2004 12
# 2005 16
# 2006 50
# 2007 10
# 2008 20
# 2009 30
# 2010 21
# 2011 12
# 2012 13
# 2013 13
# 2014 16
# 2015 12

# %% [markdown]
# # 7. Second largest component

# %%
def size_of_2nd_largest_component(inf_year, sup_year):
    g = author_network(papers, inf_year, sup_year)
    cc = nx.connected_component_subgraphs(g)
    comps = [len(c) for c in sorted(nx.connected_components(g), key=len, reverse=True)]
    return comps[1]

# %%
for year in range(2002, 2016):
    print year, size_of_2nd_largest_component(year, year)
# Out:
# 2002 7
# 2003 11
# 2004 12
# 2005 15
# 2006 22
# 2007 10
# 2008 13
# 2009 16
# 2010 16
# 2011 9
# 2012 12
# 2013 12
# 2014 15
# 2015 12

# %% [markdown]
# # 8. Mean distance

# %%
def mean_dist_year(starting_yr, ending_yr):
    g = author_network(papers, starting_yr, ending_yr)
    
    nodes = g.nodes()
    pairs = make_pairs(nodes)

    dist_list = []
    for p in pairs:
        try:
            dist_list.append(nx.shortest_path_length(g, source = str(p[0]), target = str(p[1])))
        except:
            pass

    return round(float(sum(dist_list))/len(dist_list),2)

# %%
mean_dist_year(2002, 2016)
# Out:
# 5.9

# %%
mean_dists = {}

n = 14
bar = pyprind.ProgBar(n)

for ending in range(2002, 2016):
    bar.update()
    mean_dists[ending] = round(mean_dist_year(ending, ending), 2)
# Out:
# 0%          100%
# [##############] | ETA: 00:00:00
# Total time elapsed: 00:00:04

# %%
mean_dists
# Out:
# {2002: 1.22,
#  2003: 1.51,
#  2004: 1.43,
#  2005: 1.61,
#  2006: 2.76,
#  2007: 1.35,
#  2008: 1.4,
#  2009: 1.75,
#  2010: 1.69,
#  2011: 1.32,
#  2012: 1.55,
#  2013: 1.43,
#  2014: 1.48,
#  2015: 1.35}

# %%
plt.plot(mean_dists.keys(), mean_dists.values())
plt.ylabel('Mean Distance')
plt.xlabel('Year')

# %%
plot_time_series(mean_dists, "Mean Distance", "Year","avgDegYear", (8,5), 3, None)

# %%
mean_dists = {}

n = 14
bar = pyprind.ProgBar(n)

for ending in range(2002, 2016):
    bar.update()
    mean_dists[ending] = mean_dist_year(2002, ending)

# %%
hold_mean_dists = mean_dists

# %%
plot_time_series(hold_mean_dists, "Maximum Distance", "Year","avgDegYear", (8,5), 6.4, None)

# %% [markdown]
# # 9. Maximum distance

# %%
def max_dist_year(starting_yr, ending_yr):
    g = author_network(papers, starting_yr, ending_yr)
    
    nodes = g.nodes()
    pairs = make_pairs(nodes)

    dist_list = []
    for p in pairs:
        try:
            dist_list.append(nx.shortest_path_length(g, source = str(p[0]), target = str(p[1])))
        except:
            pass

    return max(dist_list)

# %%
max_dists = {}

n = 14
bar = pyprind.ProgBar(n)

for ending in range(2002, 2016):
    bar.update()
    max_dists[ending] = max_dist_year(ending, ending)

# %%
plt.plot(max_dists.keys(), max_dists.values())
plt.ylabel('Max Distance')
plt.xlabel('Year')

# %%
plot_time_series(max_dists, "Maximum Distance", "Year","avgDegYear", (8,5), 6.4, None)

# %% [markdown]
# # 10. Clustering coefficient C

# %%
def clustering_coefficient_year(starting_yr, ending_yr):
    g = weighted_author_network(papers, starting_yr, ending_yr)
    return nx.average_clustering(g)

# %%
clustering_coefficient_year(2002, 2016)
# Out:
# 0.7069497808608101

# %%
clustering_coefficients = {}

n = 14
bar = pyprind.ProgBar(n)

for ending in range(2002, 2016):
    bar.update()
    clustering_coefficients[ending] = round(clustering_coefficient_year(ending, ending),2)
# Out:
# 0%          100%
# [##############] | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %%
clustering_coefficients
# Out:
# {2002: 0.63,
#  2003: 0.67,
#  2004: 0.67,
#  2005: 0.63,
#  2006: 0.71,
#  2007: 0.67,
#  2008: 0.75,
#  2009: 0.7,
#  2010: 0.76,
#  2011: 0.79,
#  2012: 0.74,
#  2013: 0.72,
#  2014: 0.75,
#  2015: 0.79}

# %%
plot_time_series_2(clustering_coefficients, "Clustering Coefficients", "Year","avgDegYear", (8,5), 0.6, 0.8)

# %%
clustering_coefficients = {}

n = 14
bar = pyprind.ProgBar(n)

for ending in range(2002, 2016):
    bar.update()
    clustering_coefficients[ending-2002] = clustering_coefficient_year(2002, ending)
# Out:
# 0%          100%
# [##############] | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %%
plot_time_series_2(clustering_coefficients, "Clustering Coefficients", "Number of years since 2002","avgDegYear", (8,5), 0.6, 0.71)

# %% [markdown]
# # 11. Link Prediction

# %%
def jaccard_coefficient_year(starting_yr, ending_yr):
    g = author_network(papers, starting_yr, ending_yr)
    preds = nx.jaccard_coefficient(g)
    return preds

# %%
def similar_authors(aid):
    result = {}
    preds = jaccard_coefficient_year(2002, 2015)
    for pred in preds:
        if aid in pred:
            if pred[2] > 0:
                for partner in pred[0:2]:
                    if partner != aid:
                        result[partner] = pred[2]
    
    sorted_result = sorted(result.items(), key=operator.itemgetter(1), reverse=True)
    for res in sorted_result:
        name = display_author(authors, res[0])['name']
        score = res[1]
        print name, score
    return sorted_result

# %%
info = similar_authors('3')

# %%
nx.
