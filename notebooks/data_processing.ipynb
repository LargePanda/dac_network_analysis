# %% [markdown]
# <h1 align = "center">DAC Network Construction</h1>

# %%
import json

# %% [markdown]
# ## Author Object

# %%
class Author():
    def __init__(self, name, aid):
        self.name = name
        self.aid = aid
        self.nicknames = []
        self.paper_ids = []
    
    def add_paper(self, pid):
        if pid not in self.paper_ids:
            self.paper_ids.append(pid)
            
    def add_nickname(self, name):
        if name not in self.nicknames:
            self.nicknames.append(name)

# %% [markdown]
# ## Paper Object

# %%
class Paper():
    def __init__(self, title, abstract, year, author_names, b_topic, topics, pid, detc, url):
        
        # Basic info
        self.title = title
        self.abstract = abstract
        self.year = year
        self.author_names = author_names
        self.broad_topic = b_topic
        self.topics = topics
        self.pid = pid
        self.detc = detc
        self.url = url
        
        # add later
        self.author_ids = []
        self.citations = []
        self.cited_by = []
    
    def add_author_id(self, aid):
        if aid not in self.author_ids:
            self.author_ids.append(aid)

# %% [markdown]
# ## Procedure 1. Read papers

# %%
file_path = "../2016_data/DAC_Entire_DataBase_2016.json"

with open(file_path, "r") as f:
    database = json.load(f)

stats = {}
for p in database:
    stats[p['DETC']] = p['Year']

# %%
len(database)
# Out:
# 1668

# %%
papers = {}
for p in database:
    year = p['Year']
    if p['DETC'] in stats:
        year = stats[p['DETC']]
    paper = Paper(p['Title'], p['Abstract'], year,p['Authors'], p['Broad_Topic'],\
                  p['Topics'], p['PaperID'],p['DETC'], p['URL'])
    papers[paper.pid] = paper

# %%
stats = {}

for p in papers.values():
    if p.year in stats:
        stats[p.year]+=1
    else:
        stats[p.year]=1
stats
# Out:
# {2002: 117,
#  2003: 143,
#  2004: 115,
#  2005: 128,
#  2006: 118,
#  2007: 125,
#  2008: 119,
#  2009: 122,
#  2010: 112,
#  2011: 110,
#  2012: 123,
#  2013: 114,
#  2014: 108,
#  2015: 114}

# %% [markdown]
# ## Procedure 2. Read authors

# %%
## add author into the dataset
author_names = {}

for p in papers.values():
    for n in p.author_names:
        author_names[n] = 1

# %%
# Assign IDs to each author

id = 0
for n in author_names.keys():
    author_names[n] = str(id)
    id += 1

# %%
authors = {}

for name in author_names.keys():
    authors[author_names[name]] = Author(name, author_names[name])

# %%
def make_name_to_author_dict(authors):
    ret = {}
    for author in authors.values():
        ret[author.name] = author
    return ret

# %% [markdown]
# ## 3. Build Connection (between author and paper)

# %%
name2author = make_name_to_author_dict(authors)

# %%
len(name2author)
# Out:
# 2528

# %% [markdown]
# ### Let each author has paper_id list

# %%
for paper in papers.values():
    for name in paper.author_names:
        author = name2author[name]
        
        author.add_paper(paper.pid)

# %% [markdown]
# ### Let each paper has author_id list

# %%
for paper in papers.values():
    for name in paper.author_names:
        paper.add_author_id(name2author[name].aid)

# %% [markdown]
# ## 4. Name Disambiguation

# %% [markdown]
# ### Detect similar name pairs
#
# Running the following cell will generate lines of similar names. Each line is formatted as "author_id, name, author_id, name". For each line, it the two are indeed similar, them copy and paste the line into data/disambiguation.txt file.

# %%
from fuzzywuzzy import fuzz
import Levenshtein
keys = name2author.keys()

for i in range(0, len(keys)):
    for j in range(i+1, len(keys)):
        p1 = name2author[keys[i]]
        p2 = name2author[keys[j]]
        
        first = p1.name
        second = p2.name
        
        pdist = fuzz.partial_ratio(first, second)
        dist = Levenshtein.distance(first, second)
        lv_ra = Levenshtein.ratio(first, second)
        
        if pdist >90 or dist <=2 or lv_ra >0.8:
            print p1.aid+"\t"+first+"\t"+p2.aid+"\t"+second
# Out:
# 3	James Allison	463	James T. Allison
# 5	David J. Gorsich	1769	David Gorsich
# 8	Q. Cheng	609	Heidi Q. Chen
# 11	Steve C. Wang	257	C. Wang
# 12	Niclas Stromberg	220	Niclas Strömberg
# 12	Niclas Stromberg	679	Niclas Strömberg
# 13	Yu Gu	18	P. Gu
# 13	Yu Gu	934	J. Gu
# 13	Yu Gu	989	Yu Liu
# 13	Yu Gu	1605	Xu Guo
# 13	Yu Gu	2400	Y. Fu
# 18	P. Gu	97	C. Yu
# 18	P. Gu	934	J. Gu
# 18	P. Gu	942	Ashwin P. Gurnani
# 18	P. Gu	1870	W. Hu
# 18	P. Gu	2400	Y. Fu
# 23	Le Chen	503	Jie Chen
# 23	Le Chen	691	Ken Chen
# 23	Le Chen	1414	Wei Chen
# 23	Le Chen	2018	Li Chen
# 23	Le Chen	2291	Wen Chen
# 28	Tucker J. Marion	837	Tucker Marion
# 32	J.-C. Léon	2456	J. C. Léon
# 42	Ashraf Nassef	1404	Ashraf O. Nassef
# 49	Zhe Zhang	1560	Jie Zhang
# 52	John Ziegert	1898	John C. Ziegert
# 53	Shen Lu	2255	Zhen Hu
# 60	Mian Li	118	Xiang Li
# 60	Mian Li	458	Jia Li
# 60	Mian Li	930	Meifang Li
# 60	Mian Li	1313	Yan Li
# 60	Mian Li	1339	Ming Li
# 530	Matthew Watkins	1965	Matthew Parkinson
# 76	V. Krishnamurthy	771	Vivek Krishnamurthy
# 79	James L. Mathieson	2364	James J. Mason
# 93	Chao Qi	1648	Chao Xu
# 93	Chao Qi	2042	Chao Hu
# 95	T. R. Langerak	1038	Thomas R. Langerak
# 96	Sinobu Yoshimura	317	Shinobu Yoshimura
# 96	Sinobu Yoshimura	2175	Yu Yoshimura
# 97	C. Yu	934	J. Gu
# 97	C. Yu	1870	W. Hu
# 97	C. Yu	2400	Y. Fu
# 98	Kristina Wärmefjord	958	Kristina Wärmefjord
# 101	Chun-Yu Lin	144	Chung-Yi Lin
# 84	Junfu Zhang	1689	Jun Zhang
# 118	Xiang Li	433	Jing Li
# 118	Xiang Li	813	Yang Li
# 118	Xiang Li	1339	Ming Li
# 120	Jing Han	1237	Jing Wang
# 126	Robert R. Parker	87	Robert R. Mayer
# 129	Kemper E. Lewis	385	Kemper Lewis
# 131	Yang Wang	1037	Yan Wang
# 131	Yang Wang	1237	Jing Wang
# 131	Yang Wang	1411	Yong Wang
# 140	Richard H. Crawford	1691	Richard Crawford
# 148	Samuel Drake	664	Sam Drake
# 155	Kai Liu	387	Nan Liu
# 1777	Carolyn Seepersad	1953	Carolyn C. Seepersad
# 1780	Gary Stump	2174	Gary M. Stump
# 1788	Yung-Chieh Hung	2459	Tzu-Chieh Hung
# 1795	Steve B. Shooter	1841	Steven B. Shooter
# 1112	Chan Yu	2042	Chao Hu
# 790	Matthew P. Castanier	2324	Matthew Castanier
# 1818	Dennis N. Assanis	1929	Dennis Assanis
# 1834	Zhen Jiang	2170	Zhen Huang
# 1838	Xin Wang	1646	Xin Yan
# 1848	Magnus Thor Jonsson	1947	Magnus Th. Jonsson
# 1363	G. Hua	1870	W. Hu
# 1857	Sangwon Lee	1880	Sang Hoon Lee
# 1876	Ehsan T. Esfahani	2461	Ehsan Tarkesh Esfahani
# 1870	W. Hu	2400	Y. Fu
# 1882	Erin F. MacDonald	2352	Erin MacDonald
# 1894	Tobias Larsson	2144	Tobias C. Larsson
# 1899	Horea T. Ilies	1997	Horea T. Ilieş
# 1899	Horea T. Ilies	2129	Horea Ilies
# 1960	Yi Zhang	2196	Yichi Zhang
# 1960	Yi Zhang	2442	T. Zhang
# 1997	Horea T. Ilieş	2129	Horea Ilies
# 1999	Nam H. Kim	2058	Nam Ho Kim
# 2006	Bianca Falcidieno	2418	Bianca Facidieno
# 2019	Ian H. Tseng	2242	Ian Tseng
# 2040	Fuewen Frank Liou	2195	Frank Liou
# 2047	Jie Hu	2425	Jim He
# 2075	Gary Wang	766	G. Gary Wang
# 2123	Ji Sun Kim	2238	Jihun Kim
# 2157	Lei Wang	2273	Lv Wang
# 2170	Zhen Huang	2255	Zhen Hu
# 2170	Zhen Huang	2365	Ke-Zheng Huang
# 2173	Eliot H. Winer	333	Eliot Winer
# 2175	Yu Yoshimura	2254	M. Yoshimura
# 2232	David Shahan	2414	David W. Shahan
# 2245	W. F. Lu	2337	Wen F. Lu
# 2483	Ke Fu	2400	Y. Fu
# 1119	Richard J. Malak, Jr.	1687	Richard J. Malak
# 2319	Y. Kang	2491	Y. Song
# 2373	Z. Dong	2491	Y. Song
# 2504	Kwun-Lon Ting	2514	Kwun-lon Ting

# %% [markdown]
# ### Function for merging name1 and name2

# %%
def merge(id1, id2, authors, papers):
    author1 = authors[id1]
    author2 = authors[id2]
    
    # 1. On Author level
    
    # let 1 has 2's all paper_ids
    for pid in author2.paper_ids:
        author1.add_paper(pid)
    
    # make 2's name as 1's nickname
    author1.add_nickname(author2.name)
    
    # 2. On Papers level
    # Make author2's papers that contain author2.id now contain author1.id
    for pid in author2.paper_ids:
        paper = papers[pid]
        paper.author_ids = [id1 if x == id2 else x for x in paper.author_ids]
    
    # remove id2
    authors.pop(id2)
    
    print author1.name, " AND ", author2.name, "ARE MERGED!"

# %% [markdown]
# ### Read from disambiguation file
#
# Think of these name pairs as edges in graph, we need to find connected components of that graph and each component is referring to a person's name set.

# %%
import networkx as nx
G=nx.Graph()
disamb_file_path = "../process_data/dis.txt"

dependency = []
with open(disamb_file_path, "rb") as f:
    for line in f:
        segs = line.strip().split("\t")
# Brandon M. Haley  AND  Brandon Haley ARE MERGED!
# David Shahan  AND  David W. Shahan ARE MERGED!
# Magnus Thor Jonsson  AND  Magnus Th. Jonsson ARE MERGED!
# J. S. M. Vergeest  AND  Joris S. M. Vergeest ARE MERGED!
# Matthew McIntire  AND  Matthew G. McIntire ARE MERGED!
# Mohamed M. Shalaby  AND  Mohammed Shalaby ARE MERGED!
# Cristina H. Amon  AND  Cristina Amon ARE MERGED!
# Ehsan T. Esfahani  AND  Ehsan Tarkesh Esfahani ARE MERGED!
# Erin F. MacDonald  AND  Erin MacDonald ARE MERGED!
# R. D. Sriram  AND  Ram D. Sriram ARE MERGED!
# Junqiang Zhang  AND  Jian Zhang ARE MERGED!
# Harrison M. Kim  AND  Harrison Kim ARE MERGED!
# Jeremy J. Michalek  AND  Jeremy Michalek ARE MERGED!
# Warren P. Seering  AND  Warren Seering ARE MERGED!
# Kwun-Lon Ting  AND  Kwun-lon Ting ARE MERGED!
# Alejandro Diaz  AND  Alejandro R. Diaz ARE MERGED!
# Mustafa H. Arafa  AND  Mustafa Arafa ARE MERGED!
# George Cheng  AND  George H. Cheng ARE MERGED!
# Mohamed Trabia  AND  Mohamed B. Trabia ARE MERGED!
# David W. Rosen  AND  David Rosen ARE MERGED!
# Sanjay B. Joshi  AND  Sanjay Joshi ARE MERGED!
# Raj Mishra  AND  Rajul Misra ARE MERGED!

# %%
authors.keys()
# Out:
# ['344',
#  '345',
#  '346',
#  '347',
#  '340',
#  '341',
#  '342',
#  '343',
#  '348',
#  '349',
#  '1653',
#  '2318',
#  '2319',
#  '2316',
#  '2317',
#  '2314',
#  '2315',
#  '2312',
#  '2313',
#  '2310',
#  '2311',
#  '298',
#  '299',
#  '296',
#  '297',
#  '294',
#  '295',
#  '292',
#  '293',
#  '290',
#  '291',
#  '2147',
#  '270',
#  '271',
#  '273',
#  '274',
#  '275',
#  '276',
#  '277',
#  '278',
#  '279',
#  '1780',
#  '2146',
#  '2268',
#  '2269',
#  '2262',
#  '2263',
#  '2260',
#  '2261',
#  '2266',
#  '2267',
#  '2264',
#  '2265',
#  '2442',
#  '2443',
#  '2440',
#  '2441',
#  '1781',
#  '2447',
#  '2444',
#  '2445',
#  '2448',
#  '2449',
#  '2189',
#  '108',
#  '109',
#  '102',
#  '103',
#  '100',
#  '101',
#  '106',
#  '107',
#  '104',
#  '105',
#  '2046',
#  '2047',
#  '2044',
#  '2045',
#  '2042',
#  '2043',
#  '2041',
#  '2048',
#  '1372',
#  '2038',
#  '1001',
#  '1210',
#  '1375',
#  '1655',
#  '1374',
#  '99',
#  '98',
#  '91',
#  '90',
#  '93',
#  '92',
#  '95',
#  '94',
#  '97',
#  '96',
#  '1623',
#  '1622',
#  '1621',
#  '1620',
#  '1627',
#  '1626',
#  '1624',
#  '1998',
#  '1629',
#  '1377',
#  '559',
#  '558',
#  '555',
#  '554',
#  '557',
#  '556',
#  '551',
#  '550',
#  '553',
#  '552',
#  '1439',
#  '1199',
#  '1198',
#  '1191',
#  '1190',
#  '1193',
#  '1192',
#  '1194',
#  '1197',
#  '1196',
#  '1759',
#  '1758',
#  '1757',
#  '1756',
#  '1755',
#  '1753',
#  '1752',
#  '1751',
#  '1176',
#  '1175',
#  '1174',
#  '1173',
#  '1172',
#  '1171',
#  '1170',
#  '1179',
#  '1178',
#  '511',
#  '510',
#  '513',
#  '1285',
#  '1284',
#  '1287',
#  '512',
#  '1281',
#  '1280',
#  '1283',
#  '1282',
#  '1003',
#  '879',
#  '1289',
#  '1288',
#  '514',
#  '1579',
#  '1578',
#  '689',
#  '688',
#  '685',
#  '684',
#  '687',
#  '686',
#  '681',
#  '680',
#  '683',
#  '682',
#  '458',
#  '1226',
#  '621',
#  '873',
#  '1224',
#  '1223',
#  '1222',
#  '1221',
#  '407',
#  '406',
#  '405',
#  '404',
#  '403',
#  '402',
#  '401',
#  '400',
#  '1379',
#  '1378',
#  '1342',
#  '409',
#  '408',
#  '453',
#  '454',
#  '2148',
#  '455',
#  '1346',
#  '1347',
#  '379',
#  '378',
#  '371',
#  '370',
#  '373',
#  '372',
#  '375',
#  '374',
#  '377',
#  '376',
#  '2295',
#  '393',
#  '392',
#  '391',
#  '390',
#  '397',
#  '396',
#  '395',
#  '394',
#  '399',
#  '398',
#  '895',
#  '2309',
#  '2308',
#  '2301',
#  '2300',
#  '2303',
#  '2302',
#  '2305',
#  '2304',
#  '2306',
#  '245',
#  '244',
#  '247',
#  '246',
#  '241',
#  '240',
#  '243',
#  '242',
#  '249',
#  '248',
#  '2275',
#  '2274',
#  '2277',
#  '2276',
#  '2271',
#  '2270',
#  '2273',
#  '2272',
#  '2279',
#  '2278',
#  '2198',
#  '2459',
#  '2458',
#  '2455',
#  '2454',
#  '2457',
#  '2451',
#  '2450',
#  '2453',
#  '2452',
#  '179',
#  '178',
#  '177',
#  '176',
#  '175',
#  '174',
#  '173',
#  '172',
#  '171',
#  '170',
#  '2051',
#  '1502',
#  '2053',
#  '2052',
#  '2055',
#  '2054',
#  '2057',
#  '1503',
#  '2059',
#  '1506',
#  '1507',
#  '1367',
#  '1504',
#  '1505',
#  '2157',
#  '1227',
#  '1977',
#  '1976',
#  '659',
#  '2405',
#  '1974',
#  '1973',
#  '1972',
#  '1971',
#  '1970',
#  '1968',
#  '1969',
#  '1618',
#  '1619',
#  '1616',
#  '1617',
#  '1614',
#  '1615',
#  '1612',
#  '1613',
#  '1610',
#  '1611',
#  '1985',
#  '1768',
#  '1762',
#  '1763',
#  '1761',
#  '1766',
#  '1767',
#  '1764',
#  '1765',
#  '1142',
#  '1143',
#  '1140',
#  '1141',
#  '1146',
#  '1147',
#  '1144',
#  '1145',
#  '1148',
#  '1149',
#  '2402',
#  '692',
#  '693',
#  '690',
#  '691',
#  '697',
#  '694',
#  '695',
#  '698',
#  '699',
#  '1548',
#  '1549',
#  '542',
#  '543',
#  '540',
#  '541',
#  '546',
#  '547',
#  '544',
#  '545',
#  '548',
#  '549',
#  '1782',
#  '1783',
#  '1784',
#  '2505',
#  '2504',
#  '2503',
#  '2502',
#  '2501',
#  '2500',
#  '2199',
#  '1807',
#  '1806',
#  '1805',
#  '1804',
#  '1803',
#  '1802',
#  '1801',
#  '1800',
#  '1809',
#  '1808',
#  '1524',
#  '1544',
#  '1525',
#  '1942',
#  '1943',
#  '1941',
#  '1946',
#  '1526',
#  '1944',
#  '1945',
#  '818',
#  '0',
#  '1527',
#  '810',
#  '811',
#  '813',
#  '814',
#  '815',
#  '816',
#  '817',
#  '1545',
#  '1522',
#  '1990',
#  '1523',
#  '1993',
#  '1490',
#  '1492',
#  '1493',
#  '1495',
#  '1496',
#  '1396',
#  '1498',
#  '1499',
#  '1395',
#  '1994',
#  '1700',
#  '1701',
#  '1702',
#  '1394',
#  '1704',
#  '1705',
#  '1706',
#  '1707',
#  '1708',
#  '1393',
#  '1996',
#  '1392',
#  '1391',
#  '1390',
#  '1128',
#  '1129',
#  '1628',
#  '1120',
#  '1121',
#  '1122',
#  '1123',
#  '1124',
#  '1125',
#  '1126',
#  '1127',
#  '524',
#  '525',
#  '526',
#  '527',
#  '520',
#  '521',
#  '522',
#  '523',
#  '1014',
#  '1015',
#  '1016',
#  '1017',
#  '528',
#  '529',
#  '1012',
#  '1234',
#  '1235',
#  '1236',
#  '1237',
#  '1230',
#  '1231',
#  '1232',
#  '1233',
#  '1238',
#  '1239',
#  '2526',
#  '438',
#  '439',
#  '436',
#  '437',
#  '434',
#  '435',
#  '432',
#  '433',
#  '430',
#  '431',
#  '2481',
#  '1967',
#  '1960',
#  '1961',
#  '2464',
#  '2465',
#  '2466',
#  '2467',
#  '238',
#  '239',
#  '234',
#  '235',
#  '236',
#  '237',
#  '230',
#  '231',
#  '232',
#  '233',
#  '2462',
#  '2229',
#  '2226',
#  '2227',
#  '2224',
#  '2225',
#  '2222',
#  '2223',
#  '2220',
#  '2221',
#  '1',
#  '146',
#  '147',
#  '144',
#  '145',
#  '142',
#  '143',
#  '140',
#  '141',
#  '2468',
#  '148',
#  '149',
#  '2088',
#  '2082',
#  '2083',
#  '2080',
#  '2081',
#  '2086',
#  '2084',
#  '2085',
#  '1832',
#  '1833',
#  '1830',
#  '1831',
#  '1836',
#  '1837',
#  '1834',
#  '1835',
#  '2155',
#  '939',
#  '938',
#  '2150',
#  '2152',
#  '2153',
#  '933',
#  '932',
#  '931',
#  '930',
#  '937',
#  '936',
#  '935',
#  '934',
#  '1955',
#  '1954',
#  '1957',
#  '1956',
#  '1951',
#  '1950',
#  '1952',
#  '1959',
#  '1958',
#  '829',
#  '828',
#  '825',
#  '824',
#  '827',
#  '826',
#  '821',
#  '820',
#  '823',
#  '822',
#  '1536',
#  '2409',
#  '1483',
#  '1482',
#  '1481',
#  '1480',
#  '1487',
#  '1486',
#  '1485',
#  '1484',
#  '1489',
#  '1488',
#  '797',
#  '796',
#  '795',
#  '794',
#  '793',
#  '792',
#  '791',
#  '790',
#  '1719',
#  '1718',
#  '2413',
#  '799',
#  '798',
#  '1270',
#  '2412',
#  '1271',
#  '2415',
#  '1272',
#  '1139',
#  '1138',
#  '2417',
#  '1133',
#  '1132',
#  '1131',
#  '1130',
#  '1137',
#  '1136',
#  '1135',
#  '1134',
#  '1276',
#  '1277',
#  '519',
#  '518',
#  '2149',
#  '1009',
#  '1008',
#  '1007',
#  '1006',
#  '1005',
#  '1004',
#  '515',
#  '1002',
#  '517',
#  '1000',
#  '623',
#  '622',
#  '1225',
#  '620',
#  '627',
#  '626',
#  '625',
#  '624',
#  '629',
#  '628',
#  '1229',
#  '1228',
#  '1535',
#  '2',
#  '1286',
#  '11',
#  '10',
#  '13',
#  '12',
#  '15',
#  '14',
#  '17',
#  '16',
#  '19',
#  '18',
#  '2382',
#  '1534',
#  '201',
#  '200',
#  '203',
#  '202',
#  '205',
#  '204',
#  '207',
#  '206',
#  '209',
#  '208',
#  '1573',
#  '1572',
#  '1571',
#  '2239',
#  '2238',
#  '1570',
#  '2231',
#  '1577',
#  '2233',
#  '2232',
#  '2235',
#  '2234',
#  '2237',
#  '1576',
#  '1575',
#  '1574',
#  '2185',
#  '2184',
#  '2095',
#  '2094',
#  '2097',
#  '2096',
#  '2091',
#  '2090',
#  '2093',
#  '2092',
#  '2099',
#  '2098',
#  '2525',
#  '2524',
#  '2527',
#  '2521',
#  '2520',
#  '2523',
#  '2522',
#  '1829',
#  '1828',
#  '1824',
#  '1827',
#  '1826',
#  '1821',
#  '1820',
#  '1823',
#  '1822',
#  '928',
#  '929',
#  '2145',
#  '2143',
#  '2142',
#  '2140',
#  '920',
#  '921',
#  '922',
#  '923',
#  '924',
#  '925',
#  '926',
#  '927',
#  '2411',
#  '1920',
#  '1921',
#  '1922',
#  '1923',
#  '1924',
#  '1925',
#  '1927',
#  '1928',
#  '832',
#  '833',
#  '830',
#  '831',
#  '836',
#  '834',
#  '835',
#  '838',
#  '839',
#  '3',
#  '1986',
#  '2511',
#  '1987',
#  '1532',
#  '784',
#  '785',
#  '786',
#  '787',
#  '780',
#  '781',
#  '782',
#  '783',
#  '1726',
#  '1727',
#  '1724',
#  '1725',
#  '788',
#  '789',
#  '1720',
#  '1721',
#  '2355',
#  '2439',
#  '60',
#  '61',
#  '62',
#  '63',
#  '64',
#  '65',
#  '66',
#  '67',
#  '68',
#  '69',
#  '1371',
#  '1588',
#  '1589',
#  '1370',
#  '1582',
#  '1583',
#  '1580',
#  '1581',
#  '1586',
#  ...]

# %% [markdown]
# ## 5. Network Construction

# %%
import networkx as nx

# %%
def make_pairs(input_list):
    length = len(input_list)
    ret = []
    if length == 1:
        return [(input_list[0], input_list[0])]
    for i in range(0, length-1):
        for j in range(i+1, length):
            ret.append((input_list[i], input_list[j]))
    return ret

# %%
def papers_by_year(papers, inf, sup):
    ret = []
    for p in papers.values():
        if p.year <= sup and p.year >= inf:
            ret.append(p)
    return ret

# %%
def make_edges(papers_selected):
    edge_list = []
    for p in papers_selected:
        edge_list.extend(make_pairs(p.author_ids))
    return edge_list

# %%
def author_network(papers, inf_year, sup_year):
    papers_between = papers_by_year(papers, inf_year, sup_year)
    edge_list = make_edges(papers_between)
    
    G=nx.Graph()
    for edge in edge_list:
        G.add_edge(edge[0], edge[1])
    return G

# %%
def print_author_node(author_list):
    node_list = ["id\tname"]
    for author in author_list:
        node_info = "\t".join([author.aid, author.name])
        node_list.append(node_info)
    return node_list

# %%
def print_paper_node(paper_list):
    node_list = ["id\ttitle"]
    for paper in paper_list:
        node_info = "\t".join([paper.pid, paper.title])
        node_list.append(node_info)
    return node_list

# %%
def print_to_file(info_list, filename):
    with open(filename, "wb") as f:
        for line in info_list:
            f.write(line)
            f.write("\n")
    print filename, "DONE!"

# %% [markdown]
# ### 5.1 Preparation

# %%
class Interpreter():
    def __init__(self):
        self.digit_holder = {}
        self.string_holder = {}
        
    def add(self, key, value):
        self.digit_holder[key] = value
        self.string_holder[value] = key
    
    def lookup(self, key):
        if type(key) is int:
            return self.digit_holder[key]
        else:
            return self.string_holder[key]

# %%
fake_aid = Interpreter()
fake_pid = Interpreter()

for i in range(0, len(authors.keys())):
    aid = authors.keys()[i]
    fake_aid.add(i, aid)
    
for i in range(0, len(papers.keys())):
    pid = papers.keys()[i]
    fake_pid.add(i, pid)

# %%
def make_pairs(input_list):
    length = len(input_list)
    ret = []
    if length <= 1:
        return []
    for i in range(0, length-1):
        for j in range(i+1, length):
            ret.append((input_list[i], input_list[j]))
    return ret

# %% [markdown]
# # 6 Author Network Construction

# %%
def author_network(authors, papers, start_year, end_year):
    edge_list = []
    #edge_list = ["from\tto\tweight\tpaper"]
    for p in papers.values():
        if p.year < start_year or p.year > end_year:
            continue
        author_ids = p.author_ids
        edges = make_pairs(author_ids)
        for edge in edges:
            # print edge
            edge_list.append("\t".join([edge[0], edge[1], "10", p.title]))
    return edge_list

# %%
def author_from_edgelist(edge_list):
    author_set = set()
    for edge in edge_list:
        segs = edge.split("\t")
        author_set.add(segs[0])
        author_set.add(segs[1])
    return list(author_set)

# %%
def network_output(authors, papers, start_year, end_year, edge_file, node_file):
    edge_list = author_network(authors, papers, start_year, end_year)
    
    with open(edge_file, "wb") as f:
        f.write("from\tto\tweight\tpaper\n")
        for line in edge_list[0:50]:
            f.write(line.encode('utf8'))
            f.write("\n")
    node_list = author_from_edgelist(edge_list[0:50])
    
    with open(node_file, "wb") as f:
        f.write("ID\tName\tType\n")
        for au in node_list[0:50]:
            line = "\t".join([au, authors[au].name, "P"])
            f.write(line.encode('utf8'))
            f.write("\n")
    return

# %% [markdown]
# ## 10. Export

# %%
import pickle

# %%
out_au = []
for au in authors.values():
    out_au.append(au.__dict__)

with open("../process_data/Author_Data.json", "wb") as f:
    json.dump(out_au, f)

# %%
out_pp = []
for pp in papers.values():
    out_pp.append(pp.__dict__)

with open("../process_data/Paper_Data.json", "wb") as f:
    json.dump(out_pp, f)

# %%
with open("../process_data/Author_Data.pickle", "wb") as f:
    pickle.dump(authors, f)

# %%
with open("../process_data/Paper_Data.pickle", "wb") as f:
    pickle.dump(papers, f)
